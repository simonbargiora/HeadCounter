# %% [markdown]
# <a href="https://colab.research.google.com/github/simonbargiora/HeadCounter/blob/master/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np
import math
from scipy.spatial import distance

def x_coordinate_to_radial_distance(y, z, x):
    return math.sqrt(y ** 2 + z ** 2 + x ** 2)

def y_coordinate_to_radial_distance(x, z, y):
    return math.sqrt(x ** 2 + z ** 2 + y ** 2)

def z_coordinate_to_radial_distance(x, y, z):
    return math.sqrt(x ** 2 + y ** 2 + z ** 2)

def radial_distance_to_x_coordinate(r, theta, phi):
    return r * math.cos(theta) * math.sin(phi)

def radial_distance_to_y_coordinate(r, theta, phi):
    return r * math.sin(theta) * math.sin(phi)

def radial_distance_to_z_coordinate(r, phi):
    return r * math.cos(phi)

def azimuthal_angle_to_polar_angle(theta, r):
    return theta / np.tan(r)

def polar_angle_to_azimuthal_angle(phi, r):
    return phi * np.tan(r)

def polar_angle_to_radial_distance(phi, theta):
    return theta / np.tan(phi)

def radial_distance_to_polar_angle(r, theta):
    return r * np.tan(theta)

def azimuthal_angle_to_radial_distance(theta, phi):
    return theta / np.tan(phi)

def radial_distance_to_azimuthal_angle(r, phi):
    return r * np.tan(phi)

def radial_distance_to_x_coordinate(r, theta, phi):
    return r * np.cos(theta) * np.sin(phi)

def radial_distance_to_y_coordinate(r, theta, phi):
    return r * np.sin(theta) * np.sin(phi)

def radial_distance_to_z_coordinate(r, phi):
    return r * np.cos(phi)

def x_coordinate_to_volume(x):
    return (4 / 3) * math.pi * (np.sqrt(y_coordinates ** 2 + z_coordinates ** 2 + x ** 2)) ** 3

def y_coordinate_to_volume(y):
    return (4 / 3) * math.pi * (np.sqrt(x_coordinates ** 2 + z_coordinates ** 2 + y ** 2)) ** 3

def z_coordinate_to_volume(z):
    return (4 / 3) * math.pi * (np.sqrt(x_coordinates ** 2 + y_coordinates ** 2 + z ** 2)) ** 3

def x_coordinate_to_surface_area(x):
    return 4 * math.pi * (np.sqrt(y_coordinates ** 2 + z_coordinates ** 2 + x ** 2)) ** 2

def y_coordinate_to_surface_area(y):
    return 4 * math.pi * (np.sqrt(x_coordinates ** 2 + z_coordinates ** 2 + y ** 2)) ** 2

def z_coordinate_to_surface_area(z):
    return 4 * math.pi * (np.sqrt(x_coordinates ** 2 + y_coordinates ** 2 + z ** 2)) ** 2

def x_coordinate_to_circumference(x):
    return 2 * math.pi * np.sqrt(y_coordinates ** 2 + z_coordinates ** 2 + x ** 2)

def y_coordinate_to_circumference(y):
    return 2 * math.pi * np.sqrt(x_coordinates ** 2 + z_coordinates ** 2 + y ** 2)

def z_coordinate_to_circumference(z):
    return 2 * math.pi * np.sqrt(x_coordinates ** 2 + y_coordinates ** 2 + z ** 2)
def z_coordinate_to_latitude(z, r):
    return math.asin(z / r)

def calculate_longitude(x, y):
 return longitude
def generate_random_points(num_points):
    points = []
    for _ in range(num_points):
        # Generate random Cartesian coordinates on the sphere
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        z = random.uniform(-1, 1)

        # Normalize the coordinates to lie on the sphere
        magnitude = math.sqrt(x**2 + y**2 + z**2)
        x /= magnitude
        y /= magnitude
        z /= magnitude

        points.append((x, y, z))

    return points

def calculate_latitude_longitude(points):
    latitudes = []
    longitudes = []

    for point in points:
        x, y, z = point
        longitude = math.degrees(math.atan2(y, x))
        latitude = math.degrees(math.asin(z))

        latitudes.append(latitude)
        longitudes.append(longitude)

    return latitudes, longitudes

def calculate_longitude(x, y):
    # Calculate the longitude for a point given x and y coordinates
    longitude = math.degrees(math.atan2(y, x))
    return longitude

def divide_into_hemispheres(points):
    hemisphere1 = []
    hemisphere2 = []

    for point in points:
        x, y, z = point

        if z >= 0:
            hemisphere1.append(point)
        else:
            hemisphere2.append(point)

    return hemisphere1, hemisphere2

def calculate_latitude_longitude(points):
    latitudes = []
    longitudes = []

    for point in points:
        x, y, z = point
        longitude = calculate_longitude(x, y)
        latitude = math.degrees(math.asin(z))

        latitudes.append(latitude)
        longitudes.append(longitude)

    return latitudes, longitudes

def calculate_sector_area(theta, radius):
    # Calculate the area of a sector on the sphere given the central angle and radius
    sector_area = (theta / 360) * (4 * math.pi * radius ** 2)
    return sector_area
central_angles = [30, 45, 60, 90]
def calculate_segment_area(theta, radius):
 segment_area = (theta / 360) * (math.pi * radius ** 2)
 return segment_area
central_angles = [30, 45, 60, 90]
def calculate_spherical_cap_surface_area(radius, height):
    # Calculate the surface area of a spherical cap given the radius (r) and height (h)
    surface_area = 2 * math.pi * radius * height
    return surface_area
def calculate_spherical_cap_volume(radius, height):
    # Calculate the volume of a spherical cap given the radius (r) and height (h)
    volume = (1/3) * math.pi * height**2 * (3*radius - height)
    return volume
def calculate_spherical_zone_surface_area(radius, height):
    # Calculate the surface area of a spherical zone given the radius (R) and height (h)
    surface_area = 2 * math.pi * radius * height
    return surface_area

def calculate_spherical_zone_volume(radius, r, height):
    # Calculate the volume of a spherical zone given the radius (R), inner radius (r), and height (h)
    volume = math.pi * height * (radius**2 - r**2)
    return volume
def calculate_spherical_segment_volume(area, radius, min_height, max_height):
    # Calculate the volume of a spherical segment given the area, radius (R), minimum height (h1),
    # and maximum height (h2)
    height = max_height - min_height
    volume = (1/3) * area * height * (3*radius - height)
    return volume
def calculate_spherical_triangle_area(radius, alpha, beta, gamma):
    # Calculate the area of a spherical triangle given the radius (R) and angles (α, β, γ)
    area = radius**2 * (alpha + beta + gamma - math.pi)
    return area
def calculate_spherical_triangle_angles(a, b, c):
    # Calculate the angles of a spherical triangle given the distances between the vertices (a, b, c)
    cos_alpha = math.cos(a) - math.cos(b) * math.cos(c)
    cos_beta = math.cos(b) - math.cos(a) * math.cos(c)
    cos_gamma = math.cos(c) - math.cos(a) * math.cos(b)

    alpha = math.acos(cos_alpha)
    beta = math.acos(cos_beta)
    gamma = math.acos(cos_gamma)

    return alpha, beta, gamma
def generate_random_spherical_coordinates():
    # Generate random spherical coordinates on the surface of a sphere
    theta = random.uniform(0, 2*math.pi)  # Azimuthal angle (0 to 2π)
    phi = random.uniform(0, math.pi)      # Polar angle (0 to π)

    return theta, phi

def convert_spherical_to_cartesian(theta, phi, radius):
    # Convert spherical coordinates to Cartesian coordinates
    x = radius * math.sin(phi) * math.cos(theta)
    y = radius * math.sin(phi) * math.sin(theta)
    z = radius * math.cos(phi)

    return x, y, z

def calculate_spherical_triangle_angles(a, b, c):
    # Calculate the angles of a spherical triangle given the distances between the vertices (a, b, c)
    cos_alpha = math.cos(a) - math.cos(b) * math.cos(c)
    cos_beta = math.cos(b) - math.cos(a) * math.cos(c)
    cos_gamma = math.cos(c) - math.cos(a) * math.cos(b)

    alpha = math.acos(cos_alpha)
    beta = math.acos(cos_beta)
    gamma = math.acos(cos_gamma)

    return alpha, beta, gamma

def calculate_spherical_triangle_area(radius, alpha, beta, gamma):
    # Calculate the area of a spherical triangle given the radius (R) and angles (α, β, γ)
    area = radius**2 * (alpha + beta + gamma - math.pi)
    return area
def calculate_law_of_sines_sides(a, b, c, A, B, C):
    # Calculate the missing sides of a triangle using the Law of Sines
    sin_A = math.sin(A)
    sin_B = math.sin(B)
    sin_C = math.sin(C)

    if a == 0:  # Calculate side a
        a = (sin_A * b) / sin_B
        c = (sin_C * b) / sin_B
    elif b == 0:  # Calculate side b
        b = (sin_B * a) / sin_A
        c = (sin_C * a) / sin_A
    else:  # Calculate side c
        c = (sin_C * a) / sin_A
        b = (sin_B * a) / sin_A

    return a, b, c, A, B, C
def calculate_law_of_tangents(a, b, c, A, B, C):
    # Calculate the missing angles of a spherical triangle using the Law of Tangents
    tan_a2 = math.tan(a/2)
    tan_b2 = math.tan(b/2)
    tan_c2 = math.tan(c/2)

    if A == 0:  # Calculate angle A
        A = 2 * math.atan(tan_a2 / (tan_b2 * tan_c2 * math.sin(B)))
    elif B == 0:  # Calculate angle B
        B = 2 * math.atan(tan_b2 / (tan_a2 * tan_c2 * math.sin(A)))
    else:  # Calculate angle C
        C = 2 * math.atan(tan_c2 / (tan_a2 * tan_b2 * math.sin(A)))

    return a, b, c, A, B, C
def calculate_spherical_polygon_area(radius, spherical_triangles):
    # Calculate the area of a spherical polygon given the radius (R) and a list of spherical triangles
    total_area = 0.0

    # Calculate the sum of spherical triangles
    for triangle in spherical_triangles:
        alpha, beta, gamma = triangle

        # Calculate the area of the spherical triangle
        triangle_area = radius**2 * (alpha + beta + gamma - math.pi)
        total_area += triangle_area

    # Calculate the excess angle
    excess = (len(spherical_triangles) - 2) * math.pi

    # Calculate the area of the spherical polygon
    polygon_area = total_area + (2*math.pi*radius*excess)
    return polygon_area
def generate_random_point_on_sphere(radius):
    # Generate random spherical coordinates for a point on a sphere
    theta = random.uniform(0, 2*math.pi)
    phi = random.uniform(0, math.pi)

    # Convert spherical coordinates to Cartesian coordinates
    x = radius * math.sin(phi) * math.cos(theta)
    y = radius * math.sin(phi) * math.sin(theta)
    z = radius * math.cos(phi)

    return x, y, z

def compute_distance_on_sphere(radius, point1, point2):
    # Compute the distance between two points on a sphere given the radius and the angular separation
    theta = math.acos(math.sin(point1[1]) * math.sin(point2[1]) * math.cos(point1[0] - point2[0]) + math.cos(point1[1]) * math.cos(point2[1]))
    distance = radius * theta
    return distance
def generate_random_point_on_sphere(radius):
    # Generate random spherical coordinates for a point on a sphere
    theta = random.uniform(0, 2*math.pi)
    phi = random.uniform(0, math.pi)

    # Convert spherical coordinates to Cartesian coordinates
    x = radius * math.sin(phi) * math.cos(theta)
    y = radius * math.sin(phi) * math.sin(theta)
    z = radius * math.cos(phi)

    return x, y, z

def compute_distance_on_sphere(radius, point1, point2):
    # Compute the distance between two points on a sphere given the radius and the angular separation
    theta = math.acos(math.sin(point1[1]) * math.sin(point2[1]) * math.cos(point1[0] - point2[0]) + math.cos(point1[1]) * math.cos(point2[1]))
    distance = radius * theta
    return distance

def apply_pythagorean_theorem(cos_a, cos_b):
    # Apply the Pythagorean theorem on a sphere
    cos_c = cos_a * cos_b
    c = math.acos(cos_c)
    return c

def generate_random_point_on_sphere(radius):
    # Generate random spherical coordinates for a point on a sphere
    theta = random.uniform(0, 2*math.pi)
    phi = random.uniform(0, math.pi)

    # Convert spherical coordinates to Cartesian coordinates
    x = radius * math.sin(phi) * math.cos(theta)
    y = radius * math.sin(phi) * math.sin(theta)
    z = radius * math.cos(phi)

    return x, y, z

def compute_distance_on_sphere(radius, point1, point2):
    # Compute the distance between two points on a sphere given the radius and the angular separation
    theta = math.acos(math.sin(point1[1]) * math.sin(point2[1]) * math.cos(point1[0] - point2[0]) + math.cos(point1[1]) * math.cos(point2[1]))
    distance = radius * theta
    return distance

def compute_perpendicular_distance_to_plane(radius, point, plane_normal):
    # Compute the perpendicular distance from a point to a plane on a sphere
    theta = math.acos(plane_normal[0] * point[0] + plane_normal[1] * point[1] + plane_normal[2] * point[2])
    distance = radius * math.sin(theta)
    return distance
# Generate random Cartesian coordinates
data = np.random.rand(100, 3)

radius_points = np.linalg.norm(data, axis=1)
theta_points = np.arctan2(data[:, 1], data[:, 0])
phi_points = np.arccos(data[:, 2] / radius_points)

center = np.array([0, 0, 0])
radius = 9556.51

min_value_x = 0
max_value_x = 100
min_value_y = 0
max_value_y = 100
min_value_z = 0
max_value_z = 100


x = random.uniform(min_value_x, max_value_x)
y = random.uniform(min_value_y, max_value_y)
z = random.uniform(min_value_z, max_value_z)


min_value_x = 0
max_value_x = 100
min_value_y = 0
max_value_y = 100
min_value_z = 0
max_value_z = 100
points = generate_random_points(100)

# Calculate the Euclidean distance from each point to the center
distances = np.linalg.norm(data - center, axis=1)

# Count the number of points within the sphere
num_points_within = np.sum(distances <= radius)

# Calculate the diameter, volume, circumference, and surface area of the sphere
diameter = 2 * radius
volume = (4 / 3) * np.pi * radius ** 3
circumference = 2 * np.pi * radius
surface_area = 4 * np.pi * radius ** 2
# Calculate the ratios
ratio_circumference_surface_area_volume = circumference / (surface_area / volume)
ratio_surface_area_circumference_volume = surface_area / (circumference / volume)
ratio_volume_diameter_surface_area = volume / (diameter / surface_area)
ratio_diameter_volume_surface_area = diameter / (volume / surface_area)
ratio_circumference_volume_surface_area = circumference / (volume / surface_area)
ratio_volume_circumference_surface_area = volume / (circumference / surface_area)
ratio_surface_area_diameter_volume = surface_area / (diameter / volume)
ratio_diameter_surface_area_volume = diameter / (surface_area / volume)
ratio_circumference_surface_area_diameter = circumference / (surface_area / diameter)
ratio_surface_area_circumference_diameter = surface_area / (circumference / diameter)
ratio_volume_diameter_circumference = volume / (diameter / circumference)
ratio_diameter_volume_circumference = diameter / (volume / circumference)
latitudes, longitudes = calculate_latitude_longitude(points)

# Convert Cartesian coordinates to spherical coordinates
radius_points = np.linalg.norm(data, axis=1)
theta_points = np.arctan2(data[:, 1], data[:, 0])
phi_points = np.arccos(data[:, 2] / radius_points)

# Convert Cartesian coordinates to radial distances
x_coordinates = data[:, 0]
y_coordinates = data[:, 1]
z_coordinates = data[:, 2]
radial_distance_x = np.sqrt(y_coordinates ** 2 + z_coordinates ** 2 + x_coordinates ** 2)
radial_distance_y = np.sqrt(x_coordinates ** 2 + z_coordinates ** 2 + y_coordinates ** 2)
radial_distance_z = np.sqrt(x_coordinates ** 2 + y_coordinates ** 2 + z_coordinates ** 2)
# Convert Cartesian coordinates to azimuthal angles
azimuthal_angle_x = np.arctan2(y_coordinates, x_coordinates)
azimuthal_angle_y = np.arctan2(y_coordinates, x_coordinates)

# Convert Cartesian coordinates to polar angles
polar_angle_z = np.arccos(z_coordinates / radius_points)

theta = 1.5
r = 0.8
phi = phi_points
polar_angle = azimuthal_angle_to_polar_angle(theta, r)
azimuthal_angle = polar_angle_to_azimuthal_angle(phi, r)
radial_distance = polar_angle_to_radial_distance(phi, theta)
polar_angle_2 = radial_distance_to_polar_angle(r, theta)
radial_distance_2 = azimuthal_angle_to_radial_distance(theta, phi)
azimuthal_angle_2 = radial_distance_to_azimuthal_angle(r, phi)
latitude = z_coordinate_to_latitude(z, radius)
longitude = math.degrees(math.atan2(y, x))
x_result = radial_distance_to_x_coordinate(r, theta, phi)
y_result = radial_distance_to_y_coordinate(r, theta, phi)
z_result = radial_distance_to_z_coordinate(r, phi)
surface_area_x = x_coordinate_to_surface_area(x)
surface_area_y = y_coordinate_to_surface_area(y)
surface_area_z = z_coordinate_to_surface_area(z)

circumference_x = x_coordinate_to_circumference(x)
circumference_y = y_coordinate_to_circumference(y)
circumference_z = z_coordinate_to_circumference(z)
points = generate_random_points(100)
hemisphere1, hemisphere2 = divide_into_hemispheres(points)
hemisphere1_latitudes, hemisphere1_longitudes = calculate_latitude_longitude(hemisphere1)
hemisphere2_latitudes, hemisphere2_longitudes = calculate_latitude_longitude(hemisphere2)
centroid = np.mean(data, axis=0)
distances = np.linalg.norm(data - centroid, axis=1)
radius = np.max(distances)
min_height = np.min(data[:, 2])
max_height = np.max(data[:, 2])
points_within_cap = data[(distances <= radius) & (data[:, 2] >= min_height) & (data[:, 2] <= max_height)]
surface_area = calculate_spherical_cap_surface_area(radius, max_height - min_height)
volume = calculate_spherical_cap_volume(radius, max_height - min_height)
centroid = np.mean(data, axis=0)
distances = np.linalg.norm(data - centroid, axis=1)
radius = np.max(distances)
filtered_points = data[(data[:, 2] >= min_height) & (data[:, 2] <= max_height)]
min_height = np.min(filtered_points[:, 2])
max_height = np.max(filtered_points[:, 2])
inner_radius = np.min(distances[(data[:, 2] >= min_height) & (data[:, 2] <= max_height)])

surface_area = calculate_spherical_zone_surface_area(radius, max_height - min_height)
volume = calculate_spherical_zone_volume(radius, inner_radius, max_height - min_height)
theta_a, phi_a = generate_random_spherical_coordinates()
theta_b, phi_b = generate_random_spherical_coordinates()
theta_c, phi_c = generate_random_spherical_coordinates()

# Convert spherical coordinates to Cartesian coordinates
x_a, y_a, z_a = convert_spherical_to_cartesian(theta_a, phi_a, radius)
x_b, y_b, z_b = convert_spherical_to_cartesian(theta_b, phi_b, radius)
x_c, y_c, z_c = convert_spherical_to_cartesian(theta_c, phi_c, radius)

# Calculate the sides of the spherical triangle using the dot product of Cartesian coordinates
side_a = math.acos(x_b*x_c + y_b*y_c + z_b*z_c)
side_b = math.acos(x_a*x_c + y_a*y_c + z_a*z_c)
side_c = math.acos(x_a*x_b + y_a*y_b + z_a*z_b)

# Calculate the angles of the spherical triangle using the distances between vertices
alpha, beta, gamma = calculate_spherical_triangle_angles(side_a, side_b, side_c)

# Convert the angles from radians to degrees if needed
alpha_deg = math.degrees(alpha)
beta_deg = math.degrees(beta)
gamma_deg = math.degrees(gamma)

# Calculate and print the area of the spherical triangle
area = calculate_spherical_triangle_area(radius, alpha, beta, gamma)
theta_a, phi_a = generate_random_spherical_coordinates()
theta_b, phi_b = generate_random_spherical_coordinates()
theta_c, phi_c = generate_random_spherical_coordinates()

# Convert spherical coordinates to Cartesian coordinates
x_a, y_a, z_a = convert_spherical_to_cartesian(theta_a, phi_a, radius)
x_b, y_b, z_b = convert_spherical_to_cartesian(theta_b, phi_b, radius)
x_c, y_c, z_c = convert_spherical_to_cartesian(theta_c, phi_c, radius)

# Calculate the sides of the spherical triangle using the dot product of Cartesian coordinates
side_a = math.acos(x_b*x_c + y_b*y_c + z_b*z_c)
side_b = math.acos(x_a*x_c + y_a*y_c + z_a*z_c)
side_c = math.acos(x_a*x_b + y_a*y_b + z_a*z_b)

# Calculate the angles of the spherical triangle using the distancesbetween vertices
alpha, beta, gamma = calculate_spherical_triangle_angles(side_a, side_b, side_c)

# Convert the angles from radians to degrees if needed
alpha_deg = math.degrees(alpha)
beta_deg = math.degrees(beta)
gamma_deg = math.degrees(gamma)

# Calculate the missing sides and angles using the Law of Sines
a, b, c, A, B, C = calculate_law_of_sines_sides(side_a, side_b, side_c, alpha, beta, gamma)

# Calculate the missing angles using the Law of Tangents
a, b, c, A, B, C = calculate_law_of_tangents(a, b, c, A, B, C)

# Calculate and print the area of the spherical triangle
area = calculate_spherical_triangle_area(radius, alpha, beta, gamma)

points = []
for _ in range(100):
    point = generate_random_point_on_sphere(radius)
    points.append(point)

# Choose a random point for distance comparison
random_index = random.randint(0, len(points)-1)
random_point = points[random_index]

# Compute distances between the random point and each other point
distances = []
for i in range(len(points)):
    if i != random_index:
        distance = compute_distance_on_sphere(radius, random_point, points[i])
        distances.append(distance)

points = []
for _ in range(100):
    point = generate_random_point_on_sphere(radius)
    points.append(point)

# Choose random indices for distance comparison
index_a = random.randint(0, len(points)-1)
index_b = random.randint(0, len(points)-1)
while index_b == index_a:
    index_b = random.randint(0, len(points)-1)

point_a = points[index_a]
point_b = points[index_b]

# Compute distances between the selected points and a third random point
dist_a = compute_distance_on_sphere(radius, point_a, point_b)
dist_b = compute_distance_on_sphere(radius, point_b, point_a)

# Apply the Pythagorean theorem on a sphere
cos_a = math.cos(dist_a / radius)
cos_b = math.cos(dist_b / radius)
cos_c = apply_pythagorean_theorem(cos_a, cos_b)

# Compute the distance between the selected points using the Pythagorean theorem
dist_c = radius * math.acos(cos_c)
print("Number of points within the sphere:", num_points_within)
print("Radius:", radius)
print("Diameter:", diameter)
print("Volume:", volume)
print("Circumference:", circumference)
print("Surface Area:", surface_area)
print("Circumference to Surface Area to Volume Ratio:", ratio_circumference_surface_area_volume)
print("Surface Area to Circumference to Volume Ratio:", ratio_surface_area_circumference_volume)
print("Volume to Diameter to Surface Area Ratio:", ratio_volume_diameter_surface_area)
print("Diameter to Volume to Surface Area Ratio:", ratio_diameter_volume_surface_area)
print("Circumference to Volume to Surface Area Ratio:", ratio_circumference_volume_surface_area)
print("Volume to Circumference to Surface Area Ratio:", ratio_volume_circumference_surface_area)
print("Surface Area to Diameter to Volume Ratio:", ratio_surface_area_diameter_volume)
print("Diameter to Surface Area to Volume Ratio:", ratio_diameter_surface_area_volume)
print("Circumference to Surface Area to Diameter Ratio:", ratio_circumference_surface_area_diameter)
print("Surface Area to Circumference to Diameter Ratio:", ratio_surface_area_circumference_diameter)
print("Volume to Diameter to Circumference Ratio:", ratio_volume_diameter_circumference)
print("Diameter to Volume to Circumference Ratio:", ratio_diameter_volume_circumference)

# Print converted spherical coordinates
print("Spherical Coordinates:")
for i in range(len(data)):
    print("Point", i + 1, "- r:", radius_points[i], "theta:", theta_points[i], "phi:", phi_points[i])

# Print radial distances from Cartesian coordinates
print("Radial Distances:")
for i in range(len(data)):
    print("Point", i + 1, "- x:", x_coordinates[i], "Radial Distance:", radial_distance_x[i])
    print("Point", i + 1, "- y:", y_coordinates[i], "Radial Distance:", radial_distance_y[i])
    print("Point", i + 1, "- z:", z_coordinates[i], "Radial Distance:", radial_distance_z[i])

# Print azimuthal angles from Cartesian coordinates
print("Azimuthal Angles:")
for i in range(len(data)):
    print("Point", i + 1, "- x:", x_coordinates[i], "Azimuthal Angle:", azimuthal_angle_x[i])
    print("Point", i + 1, "- y:", y_coordinates[i], "Azimuthal Angle:", azimuthal_angle_y[i])

# Print polar angles from Cartesian coordinates
print("Polar Angles:")
for i in range(len(data)):
    print("Point", i + 1, "- z:", z_coordinates[i], "Polar Angle:", polar_angle_z[i])
points = []
for _ in range(100):
    point = generate_random_point_on_sphere(radius)
    points.append(point)

# Choose a random plane represented by its normal vector
plane_normal = (random.uniform(-1, 1), random.uniform(-1, 1), random.uniform(-1, 1))
plane_normal = tuple(coord / math.sqrt(plane_normal[0]**2 + plane_normal[1]**2 + plane_normal[2]**2) for coord in plane_normal)

# Choose a random point for distance calculation
random_index = random.randint(0, len(points)-1)
random_point = points[random_index]

# Compute the perpendicular distance from the random point to the plane
distance = compute_perpendicular_distance_to_plane(radius, random_point, plane_normal)
# Print the converted values
print("Polar Angle (θ):", polar_angle)
print("Azimuthal Angle (φ):", azimuthal_angle)
print("Radial Distance (r):", radial_distance)
print("Polar Angle (θ) from Radial Distance (r):", polar_angle_2)
print("Radial Distance (r) from Azimuthal Angle (φ):", radial_distance_2)
print("Azimuthal Angle (φ) from Radial Distance (r):", azimuthal_angle_2)
print("x-coordinate:", x_result)
print("y-coordinate:", y_result)
print("z-coordinate:", z_result)
print("Surface area based on x-coordinate:", surface_area_x)
print("Surface area based on y-coordinate:", surface_area_y)
print("Surface area based on z-coordinate:", surface_area_z)
print("Number of points within the sphere:", num_points_within)
print("Radius:", radius)
print("Diameter:", diameter)
print("Volume:", volume)
print("Circumference:", circumference)
print("Surface Area:", surface_area)
print("Circumference to Surface Area to Volume Ratio:", ratio_circumference_surface_area_volume)
print("Surface Area to Circumference to Volume Ratio:", ratio_surface_area_circumference_volume)
print("Volume to Diameter to Surface Area Ratio:", ratio_volume_diameter_surface_area)
print("Diameter to Volume to Surface Area Ratio:", ratio_diameter_volume_surface_area)
print("Circumference to Volume to Surface Area Ratio:", ratio_circumference_volume_surface_area)
print("Volume to Circumference to Surface Area Ratio:", ratio_volume_circumference_surface_area)
print("Surface Area to Diameter to Volume Ratio:", ratio_surface_area_diameter_volume)
print("Diameter to Surface Area to Volume Ratio:", ratio_diameter_surface_area_volume)
print("Circumference to Surface Area to Diameter Ratio:", ratio_circumference_surface_area_diameter)
print("Surface Area to Circumference to Diameter Ratio:", ratio_surface_area_circumference_diameter)
print("Volume to Diameter to Circumference Ratio:", ratio_volume_diameter_circumference)
print("Diameter to Volume to Circumference Ratio:", ratio_diameter_volume_circumference)

# Print converted spherical coordinates
print("Spherical Coordinates:")
for i in range(len(data)):
    print("Point", i + 1, "- r:", radius_points[i], "theta:", theta_points[i], "phi:", phi_points[i])

# Print radial distances from Cartesian coordinates
print("Radial Distances:")
for i in range(len(data)):
    print("Point", i + 1, "- x:", x_coordinates[i], "Radial Distance:", radial_distance_x[i])
    print("Point", i + 1, "- y:", y_coordinates[i], "Radial Distance:", radial_distance_y[i])
    print("Point", i + 1, "- z:", z_coordinates[i], "Radial Distance:", radial_distance_z[i])

# Print azimuthal angles from Cartesian coordinates
print("Azimuthal Angles:")
for i in range(len(data)):
    print("Point", i + 1, "- x:", x_coordinates[i], "Azimuthal Angle:", azimuthal_angle_x[i])
    print("Point", i + 1, "- y:", y_coordinates[i], "Azimuthal Angle:", azimuthal_angle_y[i])

# Print polar angles from Cartesian coordinates
print("Polar Angles:")
for i in range(len(data)):
    print("Point", i + 1, "- z:", z_coordinates[i], "Polar Angle:", polar_angle_z[i])

# Print the converted values
print("Polar Angle (θ):", polar_angle)
print("Azimuthal Angle (φ):", azimuthal_angle)
print("Radial Distance (r):", radial_distance)
print("Polar Angle (θ) from Radial Distance (r):", polar_angle_2)
print("Radial Distance (r) from Azimuthal Angle (φ):", radial_distance_2)
print("Azimuthal Angle (φ) from Radial Distance (r):", azimuthal_angle_2)
print("x-coordinate:", x_result)
print("y-coordinate:", y_result)
print("z-coordinate:", z_result)
print("Surface area based on x-coordinate:", surface_area_x)
print("Surface area based on y-coordinate:", surface_area_y)
print("Surface area based on z-coordinate:", surface_area_z)
print("Circumference based on x-coordinate:", circumference_x)
print("Circumference based on y-coordinate:", circumference_y)
print("Circumference based on z-coordinate:", circumference_z)
print("Latitude based on z-coordinate:", latitude)
print(f"Longitude: {longitude}")
for i in range(len(points)):
    print(f"Point {i+1}: Latitude = {latitudes[i]}, Longitude = {longitudes[i]}")
    # Print hemisphere 1 results
print("Hemisphere 1:")
for i in range(len(hemisphere1)):

    print(f"Point {i+1}: Latitude = {hemisphere1_latitudes[i]}, Longitude = {hemisphere1_longitudes[i]}")

# Print hemisphere 2 results
print("\nHemisphere 2:")
for i in range(len(hemisphere2)):
    print(f"Point {i+1}: Latitude = {hemisphere2_latitudes[i]}, Longitude = {hemisphere2_longitudes[i]}")
for angle in central_angles:
     sector_area = calculate_sector_area(angle, radius)
print(f"Central Angle: {angle} degrees, Sector Area: {sector_area}")
for angle in central_angles:
    segment_area = calculate_segment_area(angle, radius)
    print(f"Central Angle: {angle} degrees, Segment Area: {segment_area}")
    print(f"Spherical Cap Surface Area: {surface_area}")
print(f"Spherical Cap Volume: {volume}")
print(f"Spherical Zone Surface Area: {surface_area}")
print(f"Spherical Zone Volume: {volume}")
volume = calculate_spherical_segment_volume(segment_area, radius, min_height, max_height)
print(f"Spherical Segment Volume: {volume}")
print("Spherical Triangle Angles (in degrees):")
print(f"Alpha: {alpha_deg}°, Beta: {beta_deg}°, Gamma: {gamma_deg}°")
print(f"Spherical Triangle Area: {area}")
polygon_area = calculate_spherical_polygon_area(radius, [(alpha, beta, gamma)])
print("Area of the spherical polygon:", polygon_area)
for distance in distances:
    print("Distance:", distance)
    print("Distance a:", dist_a)
print("Distance b:", dist_b)
print("Distance c (computed using the Pythagorean theorem):", dist_c)
print("Perpendicular distance from point to plane:", distance)
# Out:
# Number of points within the sphere: 100
# Radius: 0.7488228505625006
# Diameter: 19113.02
# Volume: 1.6098434414961091
# Circumference: 60045.32321991479
# Surface Area: 4.6618148499910745
# Circumference to Surface Area to Volume Ratio: 191274577.26811597
# Surface Area to Circumference to Volume Ratio: 6.987404404697261e+16
# Volume to Diameter to Surface Area Ratio: 2.1951578345457875e+17
# Diameter to Volume to Surface Area Ratio: 6.0
# Circumference to Volume to Surface Area Ratio: 18.84955592153876
# Volume to Circumference to Surface Area Ratio: 6.987404404697261e+16
# Surface Area to Diameter to Volume Ratio: 2.1951578345457875e+17
# Diameter to Surface Area to Volume Ratio: 60884588.92006667
# Circumference to Surface Area to Diameter Ratio: 1.0
# Surface Area to Circumference to Diameter Ratio: 365307533.5204
# Volume to Diameter to Circumference Ratio: 11485143815816.588
# Diameter to Volume to Circumference Ratio: 0.0003139221326614004
# Spherical Coordinates:
# Point 1 - r: 1.13386488970198 theta: 0.705377439222411 phi: 1.2166707106909138
# Point 2 - r: 1.0597175855397583 theta: 0.7689189490113462 phi: 1.4214954901412051
# Point 3 - r: 0.5580194076144726 theta: 0.8376717424725331 phi: 0.5409881651872387
# Point 4 - r: 0.809187060964219 theta: 0.7032431896589653 phi: 0.5865904231892826
# Point 5 - r: 0.8753275181052268 theta: 1.2339950752301603 phi: 1.2841541803979208
# Point 6 - r: 0.6000820799191021 theta: 1.1255565948990613 phi: 1.3824540035424737
# Point 7 - r: 1.279116496242998 theta: 0.1784151554917333 phi: 0.677772286370366
# Point 8 - r: 0.9321849668294918 theta: 0.5495672309241115 phi: 0.7549281243054161
# Point 9 - r: 0.6696433915503714 theta: 0.6141713061451824 phi: 1.2593270344768464
# Point 10 - r: 0.9828899548223721 theta: 0.18862317381033927 phi: 1.1624686218038942
# Point 11 - r: 0.6264510603357979 theta: 0.6833454072252524 phi: 0.48420046491463264
# Point 12 - r: 1.2699790622315712 theta: 0.8805937867756188 phi: 0.7643078279594345
# Point 13 - r: 1.1623789188793343 theta: 0.833191204631424 phi: 1.394030649849703
# Point 14 - r: 1.1614371091233555 theta: 1.0546166880903762 phi: 0.7693982112373654
# Point 15 - r: 0.6615788871948403 theta: 1.3212924169139577 phi: 1.3089244027675757
# Point 16 - r: 1.0346138471315027 theta: 1.2694079224070653 phi: 1.4788712967293147
# Point 17 - r: 0.6694321603404837 theta: 1.4904047328640044 phi: 0.08410536937138496
# Point 18 - r: 0.9219074896526062 theta: 0.4649063771965964 phi: 0.3990088080952982
# Point 19 - r: 1.230024599856218 theta: 0.7506731532176063 phi: 1.5478553005157807
# Point 20 - r: 1.2948601368166206 theta: 1.3904042549165632 phi: 0.6921203424366439
# Point 21 - r: 1.0051598859006663 theta: 1.3954374768585325 phi: 1.0244196484344286
# Point 22 - r: 1.3827873173529057 theta: 0.5371510521465221 phi: 0.9167202131509179
# Point 23 - r: 0.6314523490451086 theta: 1.5602521582928637 phi: 0.34093507423699027
# Point 24 - r: 0.4883208867354476 theta: 1.3995797258353866 phi: 0.27902895274130685
# Point 25 - r: 0.46759910147562317 theta: 0.6641871586721704 phi: 0.7962504042370447
# Point 26 - r: 1.0484352839319764 theta: 0.34169259327647433 phi: 1.2732940369516645
# Point 27 - r: 1.5347405209542913 theta: 0.7927791491335753 phi: 1.0740302224418181
# Point 28 - r: 1.331664716387668 theta: 1.142765739527085 phi: 0.8233632144002162
# Point 29 - r: 0.8267710673000743 theta: 0.5129070388796074 phi: 0.6249809718604337
# Point 30 - r: 0.8546053093465007 theta: 0.6214776865031489 phi: 1.1350118354416308
# Point 31 - r: 0.5560201548703333 theta: 0.4689886466430979 phi: 1.1145378012027214
# Point 32 - r: 1.3431803521684673 theta: 1.486290587074056 phi: 0.7906915703142693
# Point 33 - r: 0.9253932768254454 theta: 0.6542653460766963 phi: 0.3305488125788935
# Point 34 - r: 0.3632931902337292 theta: 0.6719048841529983 phi: 1.1162624871049331
# Point 35 - r: 1.0048221741581203 theta: 0.1885147499517807 phi: 1.5187993534195074
# Point 36 - r: 1.2689788433002418 theta: 0.4791226501478464 phi: 0.9134090361825498
# Point 37 - r: 1.0840787798238793 theta: 1.4851959845110199 phi: 0.565209074983576
# Point 38 - r: 1.3503315754929581 theta: 1.3348533771756557 phi: 0.7898286811808783
# Point 39 - r: 1.1688118287139686 theta: 1.5258297982557565 phi: 1.0148317096512194
# Point 40 - r: 1.1922844253485247 theta: 0.989912055551891 phi: 1.4856456599234742
# Point 41 - r: 0.9258464254271135 theta: 0.5889795946171801 phi: 1.3070096471045134
# Point 42 - r: 0.8571204424040224 theta: 1.4497219295960244 phi: 0.2542830776019567
# Point 43 - r: 0.922770768659544 theta: 1.2871259856130455 phi: 0.5716559709883825
# Point 44 - r: 0.9586400004939017 theta: 1.4853731901167189 phi: 1.4604916780307708
# Point 45 - r: 1.00428464685401 theta: 0.944442587920737 phi: 0.43684108992869297
# Point 46 - r: 1.574243268469833 theta: 0.769916923422473 phi: 0.9076754027825854
# Point 47 - r: 1.0676859020583593 theta: 1.2130745847198783 phi: 1.465684937459872
# Point 48 - r: 1.295385671179885 theta: 0.5144247096023389 phi: 0.7572119467189237
# Point 49 - r: 1.2075467614788493 theta: 0.6819602117732209 phi: 1.272372496297995
# Point 50 - r: 0.7454506583457582 theta: 1.025297142662064 phi: 1.562636247354906
# Point 51 - r: 1.3788461442778208 theta: 1.0557027906580871 phi: 0.8637739997093093
# Point 52 - r: 1.1026493111611613 theta: 1.5248779589781891 phi: 0.911780467161317
# Point 53 - r: 1.302227923686436 theta: 0.28356370051651997 phi: 0.7512989991401059
# Point 54 - r: 0.7847813557922263 theta: 1.0077231013888521 phi: 1.2118446004084036
# Point 55 - r: 0.6369687645540822 theta: 1.5104187150705606 phi: 1.2323310260975555
# Point 56 - r: 0.9321794453113849 theta: 0.45826061686726444 phi: 1.4023523003895513
# Point 57 - r: 0.9097048906508125 theta: 0.34948790954969405 phi: 0.8591634845411412
# Point 58 - r: 1.0132307418145459 theta: 1.156360095265038 phi: 0.9166739238658927
# Point 59 - r: 0.740457752772117 theta: 0.7053746739708432 phi: 1.193900503616915
# Point 60 - r: 1.2927624738353942 theta: 0.780422326274985 phi: 1.404605773423948
# Point 61 - r: 1.1698150941836047 theta: 0.12768601709862243 phi: 0.9939089998381624
# Point 62 - r: 0.9487936814794685 theta: 0.026050027018535083 phi: 1.0699686449320898
# Point 63 - r: 0.5298171328190295 theta: 0.8589019780894366 phi: 1.4887754214280469
# Point 64 - r: 1.1462306525498593 theta: 1.1140816574216805 phi: 1.3296613262779078
# Point 65 - r: 1.1639422516668645 theta: 0.2191115017707259 phi: 0.7316885128898146
# Point 66 - r: 1.085375603682101 theta: 0.6961329062205454 phi: 1.2805629422976226
# Point 67 - r: 0.9850001004026298 theta: 0.6674793660086092 phi: 0.7073624040835845
# Point 68 - r: 0.8577296943588008 theta: 1.0128556293896414 phi: 0.1305248630608251
# Point 69 - r: 1.1257320108616171 theta: 0.48335228042168865 phi: 1.0037810924365669
# Point 70 - r: 0.9465189437182475 theta: 1.2939553851850547 phi: 0.8736144704427642
# Point 71 - r: 1.4100191557746127 theta: 0.8720528403890512 phi: 1.1376591463405223
# Point 72 - r: 1.1639863353653788 theta: 0.7054348867787527 phi: 1.0261722490033378
# Point 73 - r: 0.984677417832931 theta: 0.6939748985227184 phi: 1.1759433730608044
# Point 74 - r: 0.5961398056645677 theta: 0.6457116199143891 phi: 0.844555999043003
# Point 75 - r: 0.9027393719753879 theta: 1.4311026780210876 phi: 0.9230876541676601
# Point 76 - r: 1.0187974242638413 theta: 0.24621630600922378 phi: 1.4715556178089604
# Point 77 - r: 0.83103211115397 theta: 1.0246980208440304 phi: 1.4924040795814346
# Point 78 - r: 0.5967158315822219 theta: 0.37689168105741233 phi: 0.14871846228310087
# Point 79 - r: 1.193028099095604 theta: 0.8895438703745656 phi: 1.1530029753043165
# Point 80 - r: 0.9080897891587125 theta: 0.7473583529525194 phi: 1.265543876846171
# Point 81 - r: 1.1271458539165435 theta: 0.43023634403673944 phi: 1.1967012496795413
# Point 82 - r: 0.6413745936768889 theta: 0.782416635506815 phi: 1.1568285626261476
# Point 83 - r: 1.1593334314693282 theta: 0.12794156389458847 phi: 0.769105984666103
# Point 84 - r: 1.1707829393162594 theta: 1.386757661037553 phi: 0.6592963163054535
# Point 85 - r: 0.9205841403351069 theta: 0.03660681413384614 phi: 0.7386643860420792
# Point 86 - r: 1.0838899645923603 theta: 0.08404645870755915 phi: 0.9073054179977823
# Point 87 - r: 0.8989499592844448 theta: 1.154352805415212 phi: 0.1449153914693159
# Point 88 - r: 0.5265485722062271 theta: 1.1226923027698397 phi: 1.5258016010685862
# Point 89 - r: 1.161826331949795 theta: 0.7618891527853557 phi: 1.3108575285307826
# Point 90 - r: 1.2227266572851911 theta: 0.7788737243590498 phi: 1.511997927888087
# Point 91 - r: 0.9721465310645471 theta: 0.09204464285013943 phi: 0.7893691358260495
# Point 92 - r: 0.5079039984073842 theta: 0.9105136718377832 phi: 1.2950740939528664
# Point 93 - r: 1.0678629507842934 theta: 1.2262660780896628 phi: 0.4573539791672975
# Point 94 - r: 0.626956337309574 theta: 1.0030676339199383 phi: 0.4308928641926304
# Point 95 - r: 1.0674296887259014 theta: 0.7978903321132137 phi: 1.5026098603332299
# Point 96 - r: 1.0272646078901428 theta: 1.101845869928947 phi: 0.9342970684192422
# Point 97 - r: 0.547826458519689 theta: 0.2417645493625108 phi: 0.49273760101669173
# Point 98 - r: 0.9764307711981052 theta: 0.028457971841224776 phi: 1.2585260013255717
# Point 99 - r: 0.6284491592174656 theta: 1.1433246608043328 phi: 0.9531774197201752
# Point 100 - r: 1.0247136533237575 theta: 1.0221020540364532 phi: 0.9639979065608315
# Radial Distances:
# Point 1 - x: 0.809720279833971 Radial Distance: 1.13386488970198
# Point 1 - y: 0.6894952452370762 Radial Distance: 1.13386488970198
# Point 1 - z: 0.39319074673743737 Radial Distance: 1.13386488970198
# Point 2 - x: 0.7531072842440911 Radial Distance: 1.0597175855397583
# Point 2 - y: 0.7286862797608716 Radial Distance: 1.0597175855397583
# Point 2 - z: 0.15762958227745538 Radial Distance: 1.0597175855397583
# Point 3 - x: 0.19230694308422536 Radial Distance: 0.5580194076144726
# Point 3 - y: 0.21354143517685387 Radial Distance: 0.5580194076144726
# Point 3 - z: 0.4783343541693581 Radial Distance: 0.5580194076144726
# Point 4 - x: 0.3416390041319457 Radial Distance: 0.809187060964219
# Point 4 - y: 0.2896578288082079 Radial Distance: 0.809187060964219
# Point 4 - z: 0.6739175266290067 Radial Distance: 0.809187060964219
# Point 5 - x: 0.2774666967681262 Radial Distance: 0.8753275181052269
# Point 5 - y: 0.7924406529093072 Radial Distance: 0.8753275181052268
# Point 5 - z: 0.24748395453748495 Radial Distance: 0.8753275181052268
# Point 6 - x: 0.2538696377813576 Radial Distance: 0.6000820799191021
# Point 6 - y: 0.5320012441504753 Radial Distance: 0.6000820799191021
# Point 6 - z: 0.11235384228028966 Radial Distance: 0.6000820799191021
# Point 7 - x: 0.7893497444808324 Radial Distance: 1.279116496242998
# Point 7 - y: 0.1423455520427982 Radial Distance: 1.279116496242998
# Point 7 - z: 0.9963953711567708 Radial Distance: 1.279116496242998
# Point 8 - x: 0.544708969577199 Radial Distance: 0.9321849668294918
# Point 8 - y: 0.3336396501534744 Radial Distance: 0.9321849668294918
# Point 8 - z: 0.6789296978999475 Radial Distance: 0.9321849668294918
# Point 9 - x: 0.5209348052557083 Radial Distance: 0.6696433915503714
# Point 9 - y: 0.36733508916756874 Radial Distance: 0.6696433915503714
# Point 9 - z: 0.20521728189052602 Radial Distance: 0.6696433915503714
# Point 10 - x: 0.8860828260252558 Radial Distance: 0.9828899548223721
# Point 10 - y: 0.16914653384356215 Radial Distance: 0.9828899548223721
# Point 10 - z: 0.3902811022872227 Radial Distance: 0.9828899548223721
# Point 11 - x: 0.2261360215595919 Radial Distance: 0.6264510603357979
# Point 11 - y: 0.18412209372062016 Radial Distance: 0.6264510603357979
# Point 11 - z: 0.5544388923524218 Radial Distance: 0.6264510603357979
# Point 12 - x: 0.5595727144694596 Radial Distance: 1.2699790622315712
# Point 12 - y: 0.677714093065533 Radial Distance: 1.2699790622315712
# Point 12 - z: 0.9167490407893667 Radial Distance: 1.2699790622315712
# Point 13 - x: 0.7695390054998481 Radial Distance: 1.1623789188793343
# Point 13 - y: 0.8468500260625056 Radial Distance: 1.1623789188793343
# Point 13 - z: 0.20440035084932795 Radial Distance: 1.1623789188793343
# Point 14 - x: 0.39880498795693364 Radial Distance: 1.1614371091233555
# Point 14 - y: 0.7027399448418074 Radial Distance: 1.1614371091233555
# Point 14 - z: 0.834294498335702 Radial Distance: 1.1614371091233555
# Point 15 - x: 0.1577898186114821 Radial Distance: 0.6615788871948403
# Point 15 - y: 0.6192363657791207 Radial Distance: 0.6615788871948403
# Point 15 - z: 0.17127556866402716 Radial Distance: 0.6615788871948403
# Point 16 - x: 0.3058246012938708 Radial Distance: 1.0346138471315027
# Point 16 - y: 0.9838075276140782 Radial Distance: 1.0346138471315027
# Point 16 - z: 0.09497302000867469 Radial Distance: 1.0346138471315027
# Point 17 - x: 0.004516072515689307 Radial Distance: 0.6694321603404837
# Point 17 - y: 0.056054859270265656 Radial Distance: 0.6694321603404837
# Point 17 - z: 0.6670658701652715 Radial Distance: 0.6694321603404837
# Point 18 - x: 0.32015140182765744 Radial Distance: 0.9219074896526062
# Point 18 - y: 0.16057976393237872 Radial Distance: 0.9219074896526062
# Point 18 - z: 0.8494884571321599 Radial Distance: 0.9219074896526062
# Point 19 - x: 0.8991940401686603 Radial Distance: 1.230024599856218
# Point 19 - y: 0.838817308491697 Radial Distance: 1.230024599856218
# Point 19 - z: 0.028215551586953103 Radial Distance: 1.230024599856218
# Point 20 - x: 0.14825844218817208 Radial Distance: 1.2948601368166206
# Point 20 - y: 0.8129335556718783 Radial Distance: 1.2948601368166206
# Point 20 - z: 0.9969058342187446 Radial Distance: 1.2948601368166206
# Point 21 - x: 0.1498312759042888 Radial Distance: 1.0051598859006663
# Point 21 - y: 0.8456505695650577 Radial Distance: 1.0051598859006663
# Point 21 - z: 0.52227588416375 Radial Distance: 1.0051598859006663
# Point 22 - x: 0.9428482634946308 Radial Distance: 1.3827873173529057
# Point 22 - y: 0.5615261012046081 Radial Distance: 1.3827873173529057
# Point 22 - z: 0.8413241674427027 Radial Distance: 1.3827873173529057
# Point 23 - x: 0.002226230967450449 Radial Distance: 0.6314523490451086
# Point 23 - y: 0.21112603261878438 Radial Distance: 0.6314523490451086
# Point 23 - z: 0.5951074788312757 Radial Distance: 0.6314523490451086
# Point 24 - x: 0.022915338497053517 Radial Distance: 0.4883208867354476
# Point 24 - y: 0.13252790631578648 Radial Distance: 0.4883208867354476
# Point 24 - z: 0.4694342656125705 Radial Distance: 0.4883208867354476
# Point 25 - x: 0.2631639210411648 Radial Distance: 0.46759910147562317
# Point 25 - y: 0.20601421055913482 Radial Distance: 0.46759910147562317
# Point 25 - z: 0.3270348840884504 Radial Distance: 0.46759910147562317
# Point 26 - x: 0.9444305443505687 Radial Distance: 1.0484352839319764
# Point 26 - y: 0.3358795528499954 Radial Distance: 1.0484352839319764
# Point 26 - z: 0.3073311202408563 Radial Distance: 1.0484352839319764
# Point 27 - x: 0.9469847050658079 Radial Distance: 1.5347405209542913
# Point 27 - y: 0.9610682726315554 Radial Distance: 1.5347405209542913
# Point 27 - z: 0.7314343513750721 Radial Distance: 1.5347405209542913
# Point 28 - x: 0.4054047856168035 Radial Distance: 1.331664716387668
# Point 28 - y: 0.8885788336428102 Radial Distance: 1.331664716387668
# Point 28 - z: 0.9052102148522325 Radial Distance: 1.331664716387668
# Point 29 - x: 0.42148333327367316 Radial Distance: 0.8267710673000742
# Point 29 - y: 0.23737163362214186 Radial Distance: 0.8267710673000743
# Point 29 - z: 0.6704900484336612 Radial Distance: 0.8267710673000743
# Point 30 - x: 0.6298727869015102 Radial Distance: 0.8546053093465007
# Point 30 - y: 0.451078469038221 Radial Distance: 0.8546053093465007
# Point 30 - z: 0.3607474488534711 Radial Distance: 0.8546053093465007
# Point 31 - x: 0.44524874934052383 Radial Distance: 0.5560201548703333
# Point 31 - y: 0.22560497567663562 Radial Distance: 0.5560201548703333
# Point 31 - z: 0.2449782822673745 Radial Distance: 0.5560201548703333
# Point 32 - x: 0.08058891143871705 Radial Distance: 1.3431803521684673
# Point 32 - y: 0.9513789942564576 Radial Distance: 1.3431803521684673
# Point 32 - z: 0.944731123173203 Radial Distance: 1.3431803521684673
# Point 33 - x: 0.2383244362068775 Radial Distance: 0.9253932768254454
# Point 33 - y: 0.18278451594673928 Radial Distance: 0.9253932768254454
# Point 33 - z: 0.875296521545999 Radial Distance: 0.9253932768254454
# Point 34 - x: 0.25545791692281283 Radial Distance: 0.3632931902337292
# Point 34 - y: 0.20318085071973147 Radial Distance: 0.3632931902337292
# Point 34 - z: 0.15950152554901786 Radial Distance: 0.3632931902337292
# Point 35 - x: 0.9856864017765614 Radial Distance: 1.0048221741581203
# Point 35 - y: 0.18804934179133126 Radial Distance: 1.0048221741581203
# Point 35 - z: 0.05222417145799341 Radial Distance: 1.0048221741581203
# Point 36 - x: 0.8914043599094621 Radial Distance: 1.2689788433002418
# Point 36 - y: 0.46308118662404896 Radial Distance: 1.2689788433002418
# Point 36 - z: 0.7754104632211797 Radial Distance: 1.2689788433002418
# Point 37 - x: 0.049640967106178935 Radial Distance: 1.0840787798238793
# Point 37 - y: 0.5784984008243121 Radial Distance: 1.0840787798238793
# Point 37 - z: 0.9154792053853041 Radial Distance: 1.0840787798238793
# Point 38 - x: 0.22418735513884758 Radial Distance: 1.3503315754929581
# Point 38 - y: 0.932478520690602 Radial Distance: 1.3503315754929581
# Point 38 - z: 0.9505888711844932 Radial Distance: 1.3503315754929581
# Point 39 - x: 0.044626787958696124 Radial Distance: 1.1688118287139686
# Point 39 - y: 0.99177559543522 Radial Distance: 1.1688118287139686
# Point 39 - z: 0.6168555009378582 Radial Distance: 1.1688118287139686
# Point 40 - x: 0.6519114863151773 Radial Distance: 1.1922844253485245
# Point 40 - y: 0.9931119609841107 Radial Distance: 1.1922844253485245
# Point 40 - z: 0.10140117301733786 Radial Distance: 1.1922844253485247
# Point 41 - x: 0.7432192762292683 Radial Distance: 0.9258464254271134
# Point 41 - y: 0.4965290393739268 Radial Distance: 0.9258464254271135
# Point 41 - z: 0.24140344648701995 Radial Distance: 0.9258464254271135
# Point 42 - x: 0.026041121676384504 Radial Distance: 0.8571204424040224
# Point 42 - y: 0.21403163727667496 Radial Distance: 0.8571204424040224
# Point 42 - z: 0.8295587809271678 Radial Distance: 0.8571204424040224
# Point 43 - x: 0.1397285776121978 Radial Distance: 0.922770768659544
# Point 43 - y: 0.47929008844760823 Radial Distance: 0.922770768659544
# Point 43 - z: 0.7760559433487263 Radial Distance: 0.922770768659544
# Point 44 - x: 0.08129340585404266 Radial Distance: 0.9586400004939017
# Point 44 - y: 0.949339687630232 Radial Distance: 0.9586400004939017
# Point 44 - z: 0.10552814885958772 Radial Distance: 0.9586400004939017
# Point 45 - x: 0.24906941846026776 Radial Distance: 1.00428464685401
# Point 45 - y: 0.3442349317936494 Radial Distance: 1.00428464685401
# Point 45 - z: 0.9099749383513644 Radial Distance: 1.00428464685401
# Point 46 - x: 0.8907272290576442 Radial Distance: 1.574243268469833
# Point 46 - y: 0.8635664182167108 Radial Distance: 1.5742432684698329
# Point 46 - z: 0.9690716759178521 Radial Distance: 1.574243268469833
# Point 47 - x: 0.3717774521774756 Radial Distance: 1.0676859020583593
# Point 47 - y: 0.9945784852643335 Radial Distance: 1.0676859020583593
# Point 47 - z: 0.11201940972840951 Radial Distance: 1.0676859020583593
# Point 48 - x: 0.7746364440339514 Radial Distance: 1.295385671179885
# Point 48 - y: 0.43781079885348073 Radial Distance: 1.295385671179885
# Point 48 - z: 0.9414266413692961 Radial Distance: 1.295385671179885
# Point 49 - x: 0.8960302930996041 Radial Distance: 1.2075467614788493
# Point 49 - y: 0.7274946882650246 Radial Distance: 1.2075467614788493
# Point 49 - z: 0.3550357355986423 Radial Distance: 1.2075467614788493
# Point 50 - x: 0.38676038928026657 Radial Distance: 0.7454506583457581
# Point 50 - y: 0.6372409936716348 Radial Distance: 0.7454506583457581
# Point 50 - z: 0.006082869083608 Radial Distance: 0.7454506583457582
# Point 51 - x: 0.5164273386399025 Radial Distance: 1.378846144277821
# Point 51 - y: 0.9123108709894882 Radial Distance: 1.378846144277821
# Point 51 - z: 0.8956608555527713 Radial Distance: 1.3788461442778208
# Point 52 - x: 0.04001523949048713 Radial Distance: 1.1026493111611613
# Point 52 - y: 0.8708304201601759 Radial Distance: 1.1026493111611613
# Point 52 - z: 0.6751952779280628 Radial Distance: 1.1026493111611613
# Point 53 - x: 0.8533878810664132 Radial Distance: 1.302227923686436
# Point 53 - y: 0.24869145795887881 Radial Distance: 1.302227923686436
# Point 53 - z: 0.951671817600979 Radial Distance: 1.302227923686436
# Point 54 - x: 0.39220771400383114 Radial Distance: 0.7847813557922263
# Point 54 - y: 0.6213299600094481 Radial Distance: 0.7847813557922263
# Point 54 - z: 0.2756881685340007 Radial Distance: 0.7847813557922263
# Point 55 - x: 0.03625467798796045 Radial Distance: 0.6369687645540822
# Point 55 - y: 0.5997357513649271 Radial Distance: 0.6369687645540822
# Point 55 - z: 0.2114990162537157 Radial Distance: 0.6369687645540822
# Point 56 - x: 0.8241682163219454 Radial Distance: 0.9321794453113849
# Point 56 - y: 0.40654922817563144 Radial Distance: 0.9321794453113849
# Point 56 - z: 0.15627857989994187 Radial Distance: 0.9321794453113849
# Point 57 - x: 0.647270107092308 Radial Distance: 0.9097048906508125
# Point 57 - y: 0.23589647650350865 Radial Distance: 0.9097048906508125
# Point 57 - z: 0.5941020526070824 Radial Distance: 0.9097048906508125
# Point 58 - x: 0.3237828370794461 Radial Distance: 1.0132307418145459
# Point 58 - y: 0.7360111256312998 Radial Distance: 1.0132307418145459
# Point 58 - z: 0.6165134495838568 Radial Distance: 1.0132307418145459
# Point 59 - x: 0.5241918255795845 Radial Distance: 0.740457752772117
# Point 59 - y: 0.4463587680621748 Radial Distance: 0.740457752772117
# Point 59 - z: 0.2725150707940639 Radial Distance: 0.740457752772117
# Point 60 - x: 0.9060011169972401 Radial Distance: 1.2927624738353942
# Point 60 - y: 0.897029456493626 Radial Distance: 1.2927624738353942
# Point 60 - z: 0.21385729807399978 Radial Distance: 1.2927624738353942
# Point 61 - x: 0.972515360011904 Radial Distance: 1.1698150941836047
# Point 61 - y: 0.12485588999462449 Radial Distance: 1.1698150941836047
# Point 61 - z: 0.6380378012738454 Radial Distance: 1.1698150941836047
# Point 62 - x: 0.8319856377925116 Radial Distance: 0.9487936814794685
# Point 62 - y: 0.021678152191646483 Radial Distance: 0.9487936814794686
# Point 62 - z: 0.45556493087144756 Radial Distance: 0.9487936814794685
# Point 63 - x: 0.34494964230282377 Radial Distance: 0.5298171328190295
# Point 63 - y: 0.39978961779969524 Radial Distance: 0.5298171328190295
# Point 63 - z: 0.0434073726837364 Radial Distance: 0.5298171328190295
# Point 64 - x: 0.4908648241509014 Radial Distance: 1.1462306525498593
# Point 64 - y: 0.9989848644633061 Radial Distance: 1.1462306525498593
# Point 64 - z: 0.2737255447147945 Radial Distance: 1.1462306525498593
# Point 65 - x: 0.7590680210444067 Radial Distance: 1.1639422516668645
# Point 65 - y: 0.16903433631550147 Radial Distance: 1.1639422516668645
# Point 65 - z: 0.8660281160501873 Radial Distance: 1.1639422516668645
# Point 66 - x: 0.7980070565991404 Radial Distance: 1.085375603682101
# Point 66 - y: 0.6668938648291994 Radial Distance: 1.085375603682101
# Point 66 - z: 0.3106082930950732 Radial Distance: 1.085375603682101
# Point 67 - x: 0.5027119043013644 Radial Distance: 0.9850001004026298
# Point 67 - y: 0.396217208842912 Radial Distance: 0.9850001004026296
# Point 67 - z: 0.7486774088241335 Radial Distance: 0.9850001004026298
# Point 68 - x: 0.05910535649799975 Radial Distance: 0.8577296943588008
# Point 68 - y: 0.09470729974730197 Radial Distance: 0.8577296943588008
# Point 68 - z: 0.8504336028125069 Radial Distance: 0.8577296943588008
# Point 69 - x: 0.8407836394302423 Radial Distance: 1.1257320108616171
# Point 69 - y: 0.44130982499074245 Radial Distance: 1.1257320108616171
# Point 69 - z: 0.6046495433816325 Radial Distance: 1.1257320108616171
# Point 70 - x: 0.19833424375930242 Radial Distance: 0.9465189437182475
# Point 70 - y: 0.6980229331842069 Radial Distance: 0.9465189437182475
# Point 70 - z: 0.6077216659942681 Radial Distance: 0.9465189437182475
# Point 71 - x: 0.8232448699783038 Radial Distance: 1.4100191557746127
# Point 71 - y: 0.979886948549135 Radial Distance: 1.4100191557746127
# Point 71 - z: 0.5918137137383874 Radial Distance: 1.4100191557746127
# Point 72 - x: 0.7579670590327954 Radial Distance: 1.1639863353653788
# Point 72 - y: 0.645501319892425 Radial Distance: 1.1639863353653788
# Point 72 - z: 0.6030573541178617 Radial Distance: 1.1639863353653788
# Point 73 - x: 0.6986876645526864 Radial Distance: 0.984677417832931
# Point 73 - y: 0.581336541606811 Radial Distance: 0.984677417832931
# Point 73 - z: 0.3787782860522415 Radial Distance: 0.984677417832931
# Point 74 - x: 0.3559836713483524 Radial Distance: 0.5961398056645677
# Point 74 - y: 0.2682193377534494 Radial Distance: 0.5961398056645677
# Point 74 - z: 0.3958745767111571 Radial Distance: 0.5961398056645677
# Point 75 - x: 0.10023955002429108 Radial Distance: 0.9027393719753879
# Point 75 - y: 0.7128932893420257 Radial Distance: 0.9027393719753879
# Point 75 - z: 0.5446774865335928 Radial Distance: 0.9027393719753879
# Point 76 - x: 0.9832104785522225 Radial Distance: 1.0187974242638413
# Point 76 - y: 0.24709593788124296 Radial Distance: 1.0187974242638413
# Point 76 - z: 0.10094029935727389 Radial Distance: 1.0187974242638413
# Point 77 - x: 0.4302768249752915 Radial Distance: 0.83103211115397
# Point 77 - y: 0.7079836489039395 Radial Distance: 0.83103211115397
# Point 77 - z: 0.06507977061168846 Radial Distance: 0.83103211115397
# Point 78 - x: 0.08221026045694513 Radial Distance: 0.5967158315822219
# Point 78 - y: 0.03253988885629977 Radial Distance: 0.5967158315822219
# Point 78 - z: 0.5901291488900404 Radial Distance: 0.5967158315822219
# Point 79 - x: 0.6867045806907182 Radial Distance: 1.193028099095604
# Point 79 - y: 0.8470148917348362 Radial Distance: 1.193028099095604
# Point 79 - z: 0.484064703598061 Radial Distance: 1.193028099095604
# Point 80 - x: 0.6352802533299055 Radial Distance: 0.9080897891587125
# Point 80 - y: 0.5886978860990009 Radial Distance: 0.9080897891587125
# Point 80 - z: 0.2729118242326152 Radial Distance: 0.9080897891587125
# Point 81 - x: 0.9535752578415084 Radial Distance: 1.1271458539165435
# Point 81 - y: 0.437602465309593 Radial Distance: 1.1271458539165435
# Point 81 - z: 0.41189329442068057 Radial Distance: 1.1271458539165435
# Point 82 - x: 0.4164484987020084 Radial Distance: 0.6413745936768889
# Point 82 - y: 0.41397256779467173 Radial Distance: 0.6413745936768889
# Point 82 - z: 0.2579897875043188 Radial Distance: 0.6413745936768889
# Point 83 - x: 0.7997181934288143 Radial Distance: 1.1593334314693282
# Point 83 - y: 0.10287915433710504 Radial Distance: 1.1593334314693282
# Point 83 - z: 0.8330190250074023 Radial Distance: 1.1593334314693282
# Point 84 - x: 0.13124424731946416 Radial Distance: 1.1707829393162594
# Point 84 - y: 0.7050645172232166 Radial Distance: 1.1707829393162597
# Point 84 - z: 0.925414320773328 Radial Distance: 1.1707829393162594
# Point 85 - x: 0.6194149656234474 Radial Distance: 0.9205841403351069
# Point 85 - y: 0.022684942476249415 Radial Distance: 0.9205841403351069
# Point 85 - z: 0.6806509040492641 Radial Distance: 0.9205841403351069
# Point 86 - x: 0.8509252942777592 Radial Distance: 1.0838899645923603
# Point 86 - y: 0.07168612948304875 Radial Distance: 1.0838899645923605
# Point 86 - z: 0.6675362894570428 Radial Distance: 1.0838899645923603
# Point 87 - x: 0.052512017029079705 Radial Distance: 0.8989499592844448
# Point 87 - y: 0.11872124723132782 Radial Distance: 0.8989499592844448
# Point 87 - z: 0.8895272805377475 Radial Distance: 0.8989499592844448
# Point 88 - x: 0.22790024270995168 Radial Distance: 0.5265485722062271
# Point 88 - y: 0.4740822190543367 Radial Distance: 0.5265485722062271
# Point 88 - z: 0.02368391525228386 Radial Distance: 0.5265485722062271
# Point 89 - x: 0.8123799395384175 Radial Distance: 1.161826331949795
# Point 89 - y: 0.77505406019682 Radial Distance: 1.161826331949795
# Point 89 - z: 0.2986142381399398 Radial Distance: 1.161826331949795
# Point 90 - x: 0.8687170346915315 Radial Distance: 1.2227266572851911
# Point 90 - y: 0.8574545734559446 Radial Distance: 1.2227266572851911
# Point 90 - z: 0.07185295075398035 Radial Distance: 1.2227266572851911
# Point 91 - x: 0.6872142433528261 Radial Distance: 0.9721465310645471
# Point 91 - y: 0.06343363200402097 Radial Distance: 0.9721465310645471
# Point 91 - z: 0.6846763001043731 Radial Distance: 0.9721465310645471
# Point 92 - x: 0.29975150403246376 Radial Distance: 0.5079039984073842
# Point 92 - y: 0.3860001885643103 Radial Distance: 0.5079039984073842
# Point 92 - z: 0.13827278060703396 Radial Distance: 0.5079039984073842
# Point 93 - x: 0.15926553366354257 Radial Distance: 1.0678629507842934
# Point 93 - y: 0.4438316572217057 Radial Distance: 1.0678629507842934
# Point 93 - z: 0.9581123271790419 Radial Distance: 1.0678629507842934
# Point 94 - x: 0.14081152969662736 Radial Distance: 0.626956337309574
# Point 94 - y: 0.2207877529810819 Radial Distance: 0.626956337309574
# Point 94 - z: 0.5696482512311408 Radial Distance: 0.626956337309574
# Point 95 - x: 0.7435672760919031 Radial Distance: 1.0674296887259014
# Point 95 - y: 0.7623808123442939 Radial Distance: 1.0674296887259014
# Point 95 - z: 0.07272787132865233 Radial Distance: 1.0674296887259014
# Point 96 - x: 0.3733593751842271 Radial Distance: 1.0272646078901428
# Point 96 - y: 0.7369232072722102 Radial Distance: 1.0272646078901428
# Point 96 - z: 0.610589500539742 Radial Distance: 1.0272646078901428
# Point 97 - x: 0.25160694004782713 Radial Distance: 0.547826458519689
# Point 97 - y: 0.06204318526238228 Radial Distance: 0.547826458519689
# Point 97 - z: 0.48265766287969714 Radial Distance: 0.547826458519689
# Point 98 - x: 0.9288329099237015 Radial Distance: 0.9764307711981052
# Point 98 - y: 0.02643983866994759 Radial Distance: 0.9764307711981052
# Point 98 - z: 0.29997901812677263 Radial Distance: 0.9764307711981052
# Point 99 - x: 0.2124052920899674 Radial Distance: 0.6284491592174656
# Point 99 - y: 0.4662464318776789 Radial Distance: 0.6284491592174657
# Point 99 - z: 0.3639321397934622 Radial Distance: 0.6284491592174656
# Point 100 - x: 0.43905004021933236 Radial Distance: 1.0247136533237575
# Point 100 - y: 0.71821165542584 Radial Distance: 1.0247136533237575
# Point 100 - z: 0.5843330826694643 Radial Distance: 1.0247136533237575
# Azimuthal Angles:
# Point 1 - x: 0.809720279833971 Azimuthal Angle: 0.705377439222411
# Point 1 - y: 0.6894952452370762 Azimuthal Angle: 0.705377439222411
# Point 2 - x: 0.7531072842440911 Azimuthal Angle: 0.7689189490113462
# Point 2 - y: 0.7286862797608716 Azimuthal Angle: 0.7689189490113462
# Point 3 - x: 0.19230694308422536 Azimuthal Angle: 0.8376717424725331
# Point 3 - y: 0.21354143517685387 Azimuthal Angle: 0.8376717424725331
# Point 4 - x: 0.3416390041319457 Azimuthal Angle: 0.7032431896589653
# Point 4 - y: 0.2896578288082079 Azimuthal Angle: 0.7032431896589653
# Point 5 - x: 0.2774666967681262 Azimuthal Angle: 1.2339950752301603
# Point 5 - y: 0.7924406529093072 Azimuthal Angle: 1.2339950752301603
# Point 6 - x: 0.2538696377813576 Azimuthal Angle: 1.1255565948990613
# Point 6 - y: 0.5320012441504753 Azimuthal Angle: 1.1255565948990613
# Point 7 - x: 0.7893497444808324 Azimuthal Angle: 0.1784151554917333
# Point 7 - y: 0.1423455520427982 Azimuthal Angle: 0.1784151554917333
# Point 8 - x: 0.544708969577199 Azimuthal Angle: 0.5495672309241115
# Point 8 - y: 0.3336396501534744 Azimuthal Angle: 0.5495672309241115
# Point 9 - x: 0.5209348052557083 Azimuthal Angle: 0.6141713061451824
# Point 9 - y: 0.36733508916756874 Azimuthal Angle: 0.6141713061451824
# Point 10 - x: 0.8860828260252558 Azimuthal Angle: 0.18862317381033927
# Point 10 - y: 0.16914653384356215 Azimuthal Angle: 0.18862317381033927
# Point 11 - x: 0.2261360215595919 Azimuthal Angle: 0.6833454072252524
# Point 11 - y: 0.18412209372062016 Azimuthal Angle: 0.6833454072252524
# Point 12 - x: 0.5595727144694596 Azimuthal Angle: 0.8805937867756188
# Point 12 - y: 0.677714093065533 Azimuthal Angle: 0.8805937867756188
# Point 13 - x: 0.7695390054998481 Azimuthal Angle: 0.833191204631424
# Point 13 - y: 0.8468500260625056 Azimuthal Angle: 0.833191204631424
# Point 14 - x: 0.39880498795693364 Azimuthal Angle: 1.0546166880903762
# Point 14 - y: 0.7027399448418074 Azimuthal Angle: 1.0546166880903762
# Point 15 - x: 0.1577898186114821 Azimuthal Angle: 1.3212924169139577
# Point 15 - y: 0.6192363657791207 Azimuthal Angle: 1.3212924169139577
# Point 16 - x: 0.3058246012938708 Azimuthal Angle: 1.2694079224070653
# Point 16 - y: 0.9838075276140782 Azimuthal Angle: 1.2694079224070653
# Point 17 - x: 0.004516072515689307 Azimuthal Angle: 1.4904047328640044
# Point 17 - y: 0.056054859270265656 Azimuthal Angle: 1.4904047328640044
# Point 18 - x: 0.32015140182765744 Azimuthal Angle: 0.4649063771965964
# Point 18 - y: 0.16057976393237872 Azimuthal Angle: 0.4649063771965964
# Point 19 - x: 0.8991940401686603 Azimuthal Angle: 0.7506731532176063
# Point 19 - y: 0.838817308491697 Azimuthal Angle: 0.7506731532176063
# Point 20 - x: 0.14825844218817208 Azimuthal Angle: 1.3904042549165632
# Point 20 - y: 0.8129335556718783 Azimuthal Angle: 1.3904042549165632
# Point 21 - x: 0.1498312759042888 Azimuthal Angle: 1.3954374768585325
# Point 21 - y: 0.8456505695650577 Azimuthal Angle: 1.3954374768585325
# Point 22 - x: 0.9428482634946308 Azimuthal Angle: 0.5371510521465221
# Point 22 - y: 0.5615261012046081 Azimuthal Angle: 0.5371510521465221
# Point 23 - x: 0.002226230967450449 Azimuthal Angle: 1.5602521582928637
# Point 23 - y: 0.21112603261878438 Azimuthal Angle: 1.5602521582928637
# Point 24 - x: 0.022915338497053517 Azimuthal Angle: 1.3995797258353866
# Point 24 - y: 0.13252790631578648 Azimuthal Angle: 1.3995797258353866
# Point 25 - x: 0.2631639210411648 Azimuthal Angle: 0.6641871586721704
# Point 25 - y: 0.20601421055913482 Azimuthal Angle: 0.6641871586721704
# Point 26 - x: 0.9444305443505687 Azimuthal Angle: 0.34169259327647433
# Point 26 - y: 0.3358795528499954 Azimuthal Angle: 0.34169259327647433
# Point 27 - x: 0.9469847050658079 Azimuthal Angle: 0.7927791491335753
# Point 27 - y: 0.9610682726315554 Azimuthal Angle: 0.7927791491335753
# Point 28 - x: 0.4054047856168035 Azimuthal Angle: 1.142765739527085
# Point 28 - y: 0.8885788336428102 Azimuthal Angle: 1.142765739527085
# Point 29 - x: 0.42148333327367316 Azimuthal Angle: 0.5129070388796074
# Point 29 - y: 0.23737163362214186 Azimuthal Angle: 0.5129070388796074
# Point 30 - x: 0.6298727869015102 Azimuthal Angle: 0.6214776865031489
# Point 30 - y: 0.451078469038221 Azimuthal Angle: 0.6214776865031489
# Point 31 - x: 0.44524874934052383 Azimuthal Angle: 0.4689886466430979
# Point 31 - y: 0.22560497567663562 Azimuthal Angle: 0.4689886466430979
# Point 32 - x: 0.08058891143871705 Azimuthal Angle: 1.486290587074056
# Point 32 - y: 0.9513789942564576 Azimuthal Angle: 1.486290587074056
# Point 33 - x: 0.2383244362068775 Azimuthal Angle: 0.6542653460766963
# Point 33 - y: 0.18278451594673928 Azimuthal Angle: 0.6542653460766963
# Point 34 - x: 0.25545791692281283 Azimuthal Angle: 0.6719048841529983
# Point 34 - y: 0.20318085071973147 Azimuthal Angle: 0.6719048841529983
# Point 35 - x: 0.9856864017765614 Azimuthal Angle: 0.1885147499517807
# Point 35 - y: 0.18804934179133126 Azimuthal Angle: 0.1885147499517807
# Point 36 - x: 0.8914043599094621 Azimuthal Angle: 0.4791226501478464
# Point 36 - y: 0.46308118662404896 Azimuthal Angle: 0.4791226501478464
# Point 37 - x: 0.049640967106178935 Azimuthal Angle: 1.4851959845110199
# Point 37 - y: 0.5784984008243121 Azimuthal Angle: 1.4851959845110199
# Point 38 - x: 0.22418735513884758 Azimuthal Angle: 1.3348533771756557
# Point 38 - y: 0.932478520690602 Azimuthal Angle: 1.3348533771756557
# Point 39 - x: 0.044626787958696124 Azimuthal Angle: 1.5258297982557565
# Point 39 - y: 0.99177559543522 Azimuthal Angle: 1.5258297982557565
# Point 40 - x: 0.6519114863151773 Azimuthal Angle: 0.989912055551891
# Point 40 - y: 0.9931119609841107 Azimuthal Angle: 0.989912055551891
# Point 41 - x: 0.7432192762292683 Azimuthal Angle: 0.5889795946171801
# Point 41 - y: 0.4965290393739268 Azimuthal Angle: 0.5889795946171801
# Point 42 - x: 0.026041121676384504 Azimuthal Angle: 1.4497219295960244
# Point 42 - y: 0.21403163727667496 Azimuthal Angle: 1.4497219295960244
# Point 43 - x: 0.1397285776121978 Azimuthal Angle: 1.2871259856130455
# Point 43 - y: 0.47929008844760823 Azimuthal Angle: 1.2871259856130455
# Point 44 - x: 0.08129340585404266 Azimuthal Angle: 1.4853731901167189
# Point 44 - y: 0.949339687630232 Azimuthal Angle: 1.4853731901167189
# Point 45 - x: 0.24906941846026776 Azimuthal Angle: 0.944442587920737
# Point 45 - y: 0.3442349317936494 Azimuthal Angle: 0.944442587920737
# Point 46 - x: 0.8907272290576442 Azimuthal Angle: 0.769916923422473
# Point 46 - y: 0.8635664182167108 Azimuthal Angle: 0.769916923422473
# Point 47 - x: 0.3717774521774756 Azimuthal Angle: 1.2130745847198783
# Point 47 - y: 0.9945784852643335 Azimuthal Angle: 1.2130745847198783
# Point 48 - x: 0.7746364440339514 Azimuthal Angle: 0.5144247096023389
# Point 48 - y: 0.43781079885348073 Azimuthal Angle: 0.5144247096023389
# Point 49 - x: 0.8960302930996041 Azimuthal Angle: 0.6819602117732209
# Point 49 - y: 0.7274946882650246 Azimuthal Angle: 0.6819602117732209
# Point 50 - x: 0.38676038928026657 Azimuthal Angle: 1.025297142662064
# Point 50 - y: 0.6372409936716348 Azimuthal Angle: 1.025297142662064
# Point 51 - x: 0.5164273386399025 Azimuthal Angle: 1.0557027906580871
# Point 51 - y: 0.9123108709894882 Azimuthal Angle: 1.0557027906580871
# Point 52 - x: 0.04001523949048713 Azimuthal Angle: 1.5248779589781891
# Point 52 - y: 0.8708304201601759 Azimuthal Angle: 1.5248779589781891
# Point 53 - x: 0.8533878810664132 Azimuthal Angle: 0.28356370051651997
# Point 53 - y: 0.24869145795887881 Azimuthal Angle: 0.28356370051651997
# Point 54 - x: 0.39220771400383114 Azimuthal Angle: 1.0077231013888521
# Point 54 - y: 0.6213299600094481 Azimuthal Angle: 1.0077231013888521
# Point 55 - x: 0.03625467798796045 Azimuthal Angle: 1.5104187150705606
# Point 55 - y: 0.5997357513649271 Azimuthal Angle: 1.5104187150705606
# Point 56 - x: 0.8241682163219454 Azimuthal Angle: 0.45826061686726444
# Point 56 - y: 0.40654922817563144 Azimuthal Angle: 0.45826061686726444
# Point 57 - x: 0.647270107092308 Azimuthal Angle: 0.34948790954969405
# Point 57 - y: 0.23589647650350865 Azimuthal Angle: 0.34948790954969405
# Point 58 - x: 0.3237828370794461 Azimuthal Angle: 1.156360095265038
# Point 58 - y: 0.7360111256312998 Azimuthal Angle: 1.156360095265038
# Point 59 - x: 0.5241918255795845 Azimuthal Angle: 0.7053746739708432
# Point 59 - y: 0.4463587680621748 Azimuthal Angle: 0.7053746739708432
# Point 60 - x: 0.9060011169972401 Azimuthal Angle: 0.780422326274985
# Point 60 - y: 0.897029456493626 Azimuthal Angle: 0.780422326274985
# Point 61 - x: 0.972515360011904 Azimuthal Angle: 0.12768601709862243
# Point 61 - y: 0.12485588999462449 Azimuthal Angle: 0.12768601709862243
# Point 62 - x: 0.8319856377925116 Azimuthal Angle: 0.026050027018535083
# Point 62 - y: 0.021678152191646483 Azimuthal Angle: 0.026050027018535083
# Point 63 - x: 0.34494964230282377 Azimuthal Angle: 0.8589019780894366
# Point 63 - y: 0.39978961779969524 Azimuthal Angle: 0.8589019780894366
# Point 64 - x: 0.4908648241509014 Azimuthal Angle: 1.1140816574216805
# Point 64 - y: 0.9989848644633061 Azimuthal Angle: 1.1140816574216805
# Point 65 - x: 0.7590680210444067 Azimuthal Angle: 0.2191115017707259
# Point 65 - y: 0.16903433631550147 Azimuthal Angle: 0.2191115017707259
# Point 66 - x: 0.7980070565991404 Azimuthal Angle: 0.6961329062205454
# Point 66 - y: 0.6668938648291994 Azimuthal Angle: 0.6961329062205454
# Point 67 - x: 0.5027119043013644 Azimuthal Angle: 0.6674793660086092
# Point 67 - y: 0.396217208842912 Azimuthal Angle: 0.6674793660086092
# Point 68 - x: 0.05910535649799975 Azimuthal Angle: 1.0128556293896414
# Point 68 - y: 0.09470729974730197 Azimuthal Angle: 1.0128556293896414
# Point 69 - x: 0.8407836394302423 Azimuthal Angle: 0.48335228042168865
# Point 69 - y: 0.44130982499074245 Azimuthal Angle: 0.48335228042168865
# Point 70 - x: 0.19833424375930242 Azimuthal Angle: 1.2939553851850547
# Point 70 - y: 0.6980229331842069 Azimuthal Angle: 1.2939553851850547
# Point 71 - x: 0.8232448699783038 Azimuthal Angle: 0.8720528403890512
# Point 71 - y: 0.979886948549135 Azimuthal Angle: 0.8720528403890512
# Point 72 - x: 0.7579670590327954 Azimuthal Angle: 0.7054348867787527
# Point 72 - y: 0.645501319892425 Azimuthal Angle: 0.7054348867787527
# Point 73 - x: 0.6986876645526864 Azimuthal Angle: 0.6939748985227184
# Point 73 - y: 0.581336541606811 Azimuthal Angle: 0.6939748985227184
# Point 74 - x: 0.3559836713483524 Azimuthal Angle: 0.6457116199143891
# Point 74 - y: 0.2682193377534494 Azimuthal Angle: 0.6457116199143891
# Point 75 - x: 0.10023955002429108 Azimuthal Angle: 1.4311026780210876
# Point 75 - y: 0.7128932893420257 Azimuthal Angle: 1.4311026780210876
# Point 76 - x: 0.9832104785522225 Azimuthal Angle: 0.24621630600922378
# Point 76 - y: 0.24709593788124296 Azimuthal Angle: 0.24621630600922378
# Point 77 - x: 0.4302768249752915 Azimuthal Angle: 1.0246980208440304
# Point 77 - y: 0.7079836489039395 Azimuthal Angle: 1.0246980208440304
# Point 78 - x: 0.08221026045694513 Azimuthal Angle: 0.37689168105741233
# Point 78 - y: 0.03253988885629977 Azimuthal Angle: 0.37689168105741233
# Point 79 - x: 0.6867045806907182 Azimuthal Angle: 0.8895438703745656
# Point 79 - y: 0.8470148917348362 Azimuthal Angle: 0.8895438703745656
# Point 80 - x: 0.6352802533299055 Azimuthal Angle: 0.7473583529525194
# Point 80 - y: 0.5886978860990009 Azimuthal Angle: 0.7473583529525194
# Point 81 - x: 0.9535752578415084 Azimuthal Angle: 0.43023634403673944
# Point 81 - y: 0.437602465309593 Azimuthal Angle: 0.43023634403673944
# Point 82 - x: 0.4164484987020084 Azimuthal Angle: 0.782416635506815
# Point 82 - y: 0.41397256779467173 Azimuthal Angle: 0.782416635506815
# Point 83 - x: 0.7997181934288143 Azimuthal Angle: 0.12794156389458847
# Point 83 - y: 0.10287915433710504 Azimuthal Angle: 0.12794156389458847
# Point 84 - x: 0.13124424731946416 Azimuthal Angle: 1.386757661037553
# Point 84 - y: 0.7050645172232166 Azimuthal Angle: 1.386757661037553
# Point 85 - x: 0.6194149656234474 Azimuthal Angle: 0.03660681413384614
# Point 85 - y: 0.022684942476249415 Azimuthal Angle: 0.03660681413384614
# Point 86 - x: 0.8509252942777592 Azimuthal Angle: 0.08404645870755915
# Point 86 - y: 0.07168612948304875 Azimuthal Angle: 0.08404645870755915
# Point 87 - x: 0.052512017029079705 Azimuthal Angle: 1.154352805415212
# Point 87 - y: 0.11872124723132782 Azimuthal Angle: 1.154352805415212
# Point 88 - x: 0.22790024270995168 Azimuthal Angle: 1.1226923027698397
# Point 88 - y: 0.4740822190543367 Azimuthal Angle: 1.1226923027698397
# Point 89 - x: 0.8123799395384175 Azimuthal Angle: 0.7618891527853557
# Point 89 - y: 0.77505406019682 Azimuthal Angle: 0.7618891527853557
# Point 90 - x: 0.8687170346915315 Azimuthal Angle: 0.7788737243590498
# Point 90 - y: 0.8574545734559446 Azimuthal Angle: 0.7788737243590498
# Point 91 - x: 0.6872142433528261 Azimuthal Angle: 0.09204464285013943
# Point 91 - y: 0.06343363200402097 Azimuthal Angle: 0.09204464285013943
# Point 92 - x: 0.29975150403246376 Azimuthal Angle: 0.9105136718377832
# Point 92 - y: 0.3860001885643103 Azimuthal Angle: 0.9105136718377832
# Point 93 - x: 0.15926553366354257 Azimuthal Angle: 1.2262660780896628
# Point 93 - y: 0.4438316572217057 Azimuthal Angle: 1.2262660780896628
# Point 94 - x: 0.14081152969662736 Azimuthal Angle: 1.0030676339199383
# Point 94 - y: 0.2207877529810819 Azimuthal Angle: 1.0030676339199383
# Point 95 - x: 0.7435672760919031 Azimuthal Angle: 0.7978903321132137
# Point 95 - y: 0.7623808123442939 Azimuthal Angle: 0.7978903321132137
# Point 96 - x: 0.3733593751842271 Azimuthal Angle: 1.101845869928947
# Point 96 - y: 0.7369232072722102 Azimuthal Angle: 1.101845869928947
# Point 97 - x: 0.25160694004782713 Azimuthal Angle: 0.2417645493625108
# Point 97 - y: 0.06204318526238228 Azimuthal Angle: 0.2417645493625108
# Point 98 - x: 0.9288329099237015 Azimuthal Angle: 0.028457971841224776
# Point 98 - y: 0.02643983866994759 Azimuthal Angle: 0.028457971841224776
# Point 99 - x: 0.2124052920899674 Azimuthal Angle: 1.1433246608043328
# Point 99 - y: 0.4662464318776789 Azimuthal Angle: 1.1433246608043328
# Point 100 - x: 0.43905004021933236 Azimuthal Angle: 1.0221020540364532
# Point 100 - y: 0.71821165542584 Azimuthal Angle: 1.0221020540364532
# Polar Angles:
# Point 1 - z: 0.39319074673743737 Polar Angle: 1.2166707106909138
# Point 2 - z: 0.15762958227745538 Polar Angle: 1.4214954901412051
# Point 3 - z: 0.4783343541693581 Polar Angle: 0.5409881651872387
# Point 4 - z: 0.6739175266290067 Polar Angle: 0.5865904231892826
# Point 5 - z: 0.24748395453748495 Polar Angle: 1.2841541803979208
# Point 6 - z: 0.11235384228028966 Polar Angle: 1.3824540035424737
# Point 7 - z: 0.9963953711567708 Polar Angle: 0.677772286370366
# Point 8 - z: 0.6789296978999475 Polar Angle: 0.7549281243054161
# Point 9 - z: 0.20521728189052602 Polar Angle: 1.2593270344768464
# Point 10 - z: 0.3902811022872227 Polar Angle: 1.1624686218038942
# Point 11 - z: 0.5544388923524218 Polar Angle: 0.48420046491463264
# Point 12 - z: 0.9167490407893667 Polar Angle: 0.7643078279594345
# Point 13 - z: 0.20440035084932795 Polar Angle: 1.394030649849703
# Point 14 - z: 0.834294498335702 Polar Angle: 0.7693982112373654
# Point 15 - z: 0.17127556866402716 Polar Angle: 1.3089244027675757
# Point 16 - z: 0.09497302000867469 Polar Angle: 1.4788712967293147
# Point 17 - z: 0.6670658701652715 Polar Angle: 0.08410536937138496
# Point 18 - z: 0.8494884571321599 Polar Angle: 0.3990088080952982
# Point 19 - z: 0.028215551586953103 Polar Angle: 1.5478553005157807
# Point 20 - z: 0.9969058342187446 Polar Angle: 0.6921203424366439
# Point 21 - z: 0.52227588416375 Polar Angle: 1.0244196484344286
# Point 22 - z: 0.8413241674427027 Polar Angle: 0.9167202131509179
# Point 23 - z: 0.5951074788312757 Polar Angle: 0.34093507423699027
# Point 24 - z: 0.4694342656125705 Polar Angle: 0.27902895274130685
# Point 25 - z: 0.3270348840884504 Polar Angle: 0.7962504042370447
# Point 26 - z: 0.3073311202408563 Polar Angle: 1.2732940369516645
# Point 27 - z: 0.7314343513750721 Polar Angle: 1.0740302224418181
# Point 28 - z: 0.9052102148522325 Polar Angle: 0.8233632144002162
# Point 29 - z: 0.6704900484336612 Polar Angle: 0.6249809718604337
# Point 30 - z: 0.3607474488534711 Polar Angle: 1.1350118354416308
# Point 31 - z: 0.2449782822673745 Polar Angle: 1.1145378012027214
# Point 32 - z: 0.944731123173203 Polar Angle: 0.7906915703142693
# Point 33 - z: 0.875296521545999 Polar Angle: 0.3305488125788935
# Point 34 - z: 0.15950152554901786 Polar Angle: 1.1162624871049331
# Point 35 - z: 0.05222417145799341 Polar Angle: 1.5187993534195074
# Point 36 - z: 0.7754104632211797 Polar Angle: 0.9134090361825498
# Point 37 - z: 0.9154792053853041 Polar Angle: 0.565209074983576
# Point 38 - z: 0.9505888711844932 Polar Angle: 0.7898286811808783
# Point 39 - z: 0.6168555009378582 Polar Angle: 1.0148317096512194
# Point 40 - z: 0.10140117301733786 Polar Angle: 1.4856456599234742
# Point 41 - z: 0.24140344648701995 Polar Angle: 1.3070096471045134
# Point 42 - z: 0.8295587809271678 Polar Angle: 0.2542830776019567
# Point 43 - z: 0.7760559433487263 Polar Angle: 0.5716559709883825
# Point 44 - z: 0.10552814885958772 Polar Angle: 1.4604916780307708
# Point 45 - z: 0.9099749383513644 Polar Angle: 0.43684108992869297
# Point 46 - z: 0.9690716759178521 Polar Angle: 0.9076754027825854
# Point 47 - z: 0.11201940972840951 Polar Angle: 1.465684937459872
# Point 48 - z: 0.9414266413692961 Polar Angle: 0.7572119467189237
# Point 49 - z: 0.3550357355986423 Polar Angle: 1.272372496297995
# Point 50 - z: 0.006082869083608 Polar Angle: 1.562636247354906
# Point 51 - z: 0.8956608555527713 Polar Angle: 0.8637739997093093
# Point 52 - z: 0.6751952779280628 Polar Angle: 0.911780467161317
# Point 53 - z: 0.951671817600979 Polar Angle: 0.7512989991401059
# Point 54 - z: 0.2756881685340007 Polar Angle: 1.2118446004084036
# Point 55 - z: 0.2114990162537157 Polar Angle: 1.2323310260975555
# Point 56 - z: 0.15627857989994187 Polar Angle: 1.4023523003895513
# Point 57 - z: 0.5941020526070824 Polar Angle: 0.8591634845411412
# Point 58 - z: 0.6165134495838568 Polar Angle: 0.9166739238658927
# Point 59 - z: 0.2725150707940639 Polar Angle: 1.193900503616915
# Point 60 - z: 0.21385729807399978 Polar Angle: 1.404605773423948
# Point 61 - z: 0.6380378012738454 Polar Angle: 0.9939089998381624
# Point 62 - z: 0.45556493087144756 Polar Angle: 1.0699686449320898
# Point 63 - z: 0.0434073726837364 Polar Angle: 1.4887754214280469
# Point 64 - z: 0.2737255447147945 Polar Angle: 1.3296613262779078
# ...
# Point 78: Latitude = -8.152442917995677, Longitude = 47.025460685479864
# Point 79: Latitude = 45.26996555550046, Longitude = -125.46186587816848
# Point 80: Latitude = 27.550771229179098, Longitude = 66.32588680571938
# Point 81: Latitude = 51.70576702193059, Longitude = 4.692940693798047
# Point 82: Latitude = -26.72087280781911, Longitude = -146.37835175999336
# Point 83: Latitude = -38.651846909242195, Longitude = -125.51402839468888
# Point 84: Latitude = -46.54222305152805, Longitude = 128.82490626003272
# Point 85: Latitude = -34.34574265366608, Longitude = -41.037687721407835
# Point 86: Latitude = 7.097061703436313, Longitude = 3.644730655895411
# Point 87: Latitude = -38.82965905065759, Longitude = 33.307532070077706
# Point 88: Latitude = -26.061526037931227, Longitude = -129.73274510531297
# Point 89: Latitude = 29.53714922793864, Longitude = -176.85123614140045
# Point 90: Latitude = 56.13121481373956, Longitude = -8.460680433929383
# Point 91: Latitude = -39.95379748707055, Longitude = -67.27523121466513
# Point 92: Latitude = -27.74882968091824, Longitude = -36.71996379585311
# Point 93: Latitude = -16.93855262941951, Longitude = -34.57616364523509
# Point 94: Latitude = 9.870266844916934, Longitude = 105.63289763285157
# Point 95: Latitude = 64.1480783841858, Longitude = -179.9967377295181
# Point 96: Latitude = 35.86985765630551, Longitude = 49.37626448240979
# Point 97: Latitude = 45.06848367744001, Longitude = -64.451971217915
# Point 98: Latitude = 44.79466624114688, Longitude = -114.98919057808475
# Point 99: Latitude = 23.363694640163917, Longitude = -48.753696705896886
# Point 100: Latitude = 44.58873630155952, Longitude = -35.86100505066013
# Hemisphere 1:
# Point 1: Latitude = 52.30164596567787, Longitude = -164.14969465823123
# Point 2: Latitude = 38.478465712577545, Longitude = 79.92504257284699
# Point 3: Latitude = 60.79926177129504, Longitude = -108.92028878023436
# Point 4: Latitude = 16.652999803774907, Longitude = -177.18819812121953
# Point 5: Latitude = 14.415968603710452, Longitude = -23.07317427261614
# Point 6: Latitude = 31.318603868291202, Longitude = 143.14533027338092
# Point 7: Latitude = 26.29391359473899, Longitude = 90.79463436687755
# Point 8: Latitude = 32.487211515993984, Longitude = -65.75795878214163
# Point 9: Latitude = 69.99466796860952, Longitude = -117.64117001376064
# Point 10: Latitude = 35.55134177716124, Longitude = 56.72925938263571
# Point 11: Latitude = 31.693661625953883, Longitude = 11.79922664714156
# Point 12: Latitude = 39.02123281658745, Longitude = 164.8512824639174
# Point 13: Latitude = 25.728673479315642, Longitude = 97.15670977324504
# Point 14: Latitude = 39.15803385750095, Longitude = -71.46970654088717
# Point 15: Latitude = 48.617700297667184, Longitude = 92.33723264193885
# Point 16: Latitude = 16.186211356012976, Longitude = 113.80325672243546
# Point 17: Latitude = 24.094104209133597, Longitude = 10.352413050901266
# Point 18: Latitude = 51.5256744176693, Longitude = 88.59872437809496
# Point 19: Latitude = 77.0581817200233, Longitude = -150.15618414857565
# Point 20: Latitude = 39.057554397531796, Longitude = -42.71912923942285
# Point 21: Latitude = 28.184974280497016, Longitude = -122.24610259268935
# Point 22: Latitude = 29.687480001828714, Longitude = 148.68601221394368
# Point 23: Latitude = 27.360127797985843, Longitude = 149.18313993287694
# Point 24: Latitude = 52.45777503782148, Longitude = -175.05901681051583
# Point 25: Latitude = 12.841154521516234, Longitude = 175.5080334149927
# Point 26: Latitude = 65.23563751981997, Longitude = 103.04796522600374
# Point 27: Latitude = 46.57266221713625, Longitude = -143.53209870042943
# Point 28: Latitude = 3.7258120777884325, Longitude = -17.64441087464266
# Point 29: Latitude = 45.84281603874028, Longitude = 113.32447653499712
# Point 30: Latitude = 25.912958949466287, Longitude = -50.681009123359686
# Point 31: Latitude = 30.067342891606394, Longitude = 62.37819555151609
# Point 32: Latitude = 38.67816997906054, Longitude = -82.28679514067447
# Point 33: Latitude = 62.19482090341361, Longitude = 77.75879267986386
# Point 34: Latitude = 19.47199622345083, Longitude = -39.70203739666006
# Point 35: Latitude = 19.40907607485273, Longitude = -30.825530144857975
# Point 36: Latitude = 52.26873099568043, Longitude = 30.71627308529023
# Point 37: Latitude = 27.494583306415112, Longitude = 62.69169593240953
# Point 38: Latitude = 20.43386905541332, Longitude = -23.427357551829726
# Point 39: Latitude = 11.588692165337529, Longitude = 58.15975256507281
# Point 40: Latitude = 42.46302291443193, Longitude = 59.39670113204357
# Point 41: Latitude = 42.17484933344883, Longitude = 155.22258944325986
# Point 42: Latitude = 35.913042812117574, Longitude = -27.806961965017976
# Point 43: Latitude = 51.174442546749766, Longitude = 130.29612697846062
# Point 44: Latitude = 17.239886042331296, Longitude = -147.69029887568095
# Point 45: Latitude = 57.33882032661653, Longitude = -83.89920310380244
# Point 46: Latitude = 26.437190410831832, Longitude = -142.077780572823
# Point 47: Latitude = 53.0943618530294, Longitude = -168.52233409441763
# Point 48: Latitude = 40.221033444130754, Longitude = -118.3014059095163
# Point 49: Latitude = 34.31062021545546, Longitude = -89.31441492348955
# Point 50: Latitude = 49.96029836779429, Longitude = 168.92774105329374
# Point 51: Latitude = 43.09122589385621, Longitude = -117.04437578462868
# Point 52: Latitude = 35.41369502418176, Longitude = -14.717415694202808
# Point 53: Latitude = 12.659302183081662, Longitude = 133.20086173317085
# Point 54: Latitude = 1.9820737876125327, Longitude = -168.5099911467987
# Point 55: Latitude = 16.197116779907084, Longitude = -42.67574508263602
#
# Hemisphere 2:
# Point 1: Latitude = -41.32978251558602, Longitude = -0.6223214733350299
# Point 2: Latitude = -17.215577614799805, Longitude = -150.38992880567173
# Point 3: Latitude = -36.641720291741855, Longitude = 83.28976529608357
# Point 4: Latitude = -3.145135475516797, Longitude = 53.56639776916781
# Point 5: Latitude = -14.98304499220888, Longitude = -114.6247455309648
# Point 6: Latitude = -0.07081705718780361, Longitude = -146.11984284455727
# Point 7: Latitude = -19.82737962614692, Longitude = -50.7156214887954
# Point 8: Latitude = -50.15333589666872, Longitude = 64.46872728822252
# Point 9: Latitude = -56.53731620401517, Longitude = -10.036118795604203
# Point 10: Latitude = -33.506648695868364, Longitude = -34.87574877149688
# Point 11: Latitude = -23.713560095395277, Longitude = 56.03573134953077
# Point 12: Latitude = -20.181133779151157, Longitude = 42.82627924388319
# Point 13: Latitude = -66.13913560943871, Longitude = -179.81018902582616
# Point 14: Latitude = -19.196718799837914, Longitude = -140.84872331233532
# Point 15: Latitude = -62.80663708740122, Longitude = 24.203428218662605
# Point 16: Latitude = -14.720817373570611, Longitude = -24.022411472683288
# Point 17: Latitude = -50.906405614816585, Longitude = -62.739878423112664
# Point 18: Latitude = -22.946307862873176, Longitude = 56.02470054557267
# Point 19: Latitude = -37.423083767008855, Longitude = -163.3770488709373
# Point 20: Latitude = -54.933696144290614, Longitude = 135.51295250335644
# Point 21: Latitude = -44.20441074745982, Longitude = -119.94846437554446
# Point 22: Latitude = -5.44044037348145, Longitude = -31.877096354776036
# Point 23: Latitude = -0.22401094757289183, Longitude = -88.8645610597391
# Point 24: Latitude = -76.67068862696954, Longitude = -147.86842165866503
# Point 25: Latitude = -52.90689148146345, Longitude = 119.11153158912045
# Point 26: Latitude = -37.18915228261906, Longitude = 57.59293063644851
# Point 27: Latitude = -7.996902824189907, Longitude = -112.38292753171416
# Point 28: Latitude = -52.01828269472692, Longitude = 176.90576291391227
# Point 29: Latitude = -4.932675831355741, Longitude = 168.31284861569395
# Point 30: Latitude = -4.660277932597874, Longitude = 15.744629683210892
# Point 31: Latitude = -36.08915074739433, Longitude = -48.79785770590088
# Point 32: Latitude = -35.088985026747665, Longitude = -84.1603768990108
# Point 33: Latitude = -15.458511210603957, Longitude = 165.01327809171121
# Point 34: Latitude = -35.85388599503601, Longitude = -80.27897586677987
# Point 35: Latitude = -12.945592820439149, Longitude = 91.61359850023776
# Point 36: Latitude = -72.99376443943218, Longitude = 165.95640950156906
# Point 37: Latitude = -36.99674428518475, Longitude = -86.91476694546543
# Point 38: Latitude = -19.072979700771615, Longitude = -14.032935859226132
# Point 39: Latitude = -34.879287875999914, Longitude = -145.0726353624649
# Point 40: Latitude = -1.215781583758593, Longitude = 102.23142915730458
# Point 41: Latitude = -13.638519150922908, Longitude = -12.36560180274803
# Point 42: Latitude = -45.210608252909175, Longitude = 70.90838651175505
# Point 43: Latitude = -21.97938011044526, Longitude = 41.46597374105779
# Point 44: Latitude = -10.348292907641472, Longitude = 112.21073813022628
# Point 45: Latitude = -41.418545286391, Longitude = 33.876566726655994
# Central Angle: 90 degrees, Sector Area: 1.7616030348513363
# Central Angle: 30 degrees, Segment Area: 0.146800252904278
# Spherical Cap Surface Area: 4.6618148499910745
# Central Angle: 45 degrees, Segment Area: 0.22020037935641704
# Spherical Cap Surface Area: 4.6618148499910745
# Central Angle: 60 degrees, Segment Area: 0.293600505808556
# Spherical Cap Surface Area: 4.6618148499910745
# Central Angle: 90 degrees, Segment Area: 0.4404007587128341
# Spherical Cap Surface Area: 4.6618148499910745
# Spherical Cap Volume: 1.6098434414961091
# Spherical Zone Surface Area: 4.6618148499910745
# Spherical Zone Volume: 1.6098434414961091
# Spherical Segment Volume: 0.18263749518157243
# Spherical Triangle Angles (in degrees):
# Alpha: 63.39051984068839°, Beta: 95.41403445546833°, Gamma: 98.97459209349577°
# Spherical Triangle Area: 0.7611998907119898
# Area of the spherical polygon: -14.01997071238388
# Distance: 0.439849124230436
# Distance a: 0.36557813847224013
# Distance: 0.4662963713314463
# Distance a: 0.36557813847224013
# Distance: 0.35097185931492236
# Distance a: 0.36557813847224013
# Distance: 0.40610440135263515
# Distance a: 0.36557813847224013
# Distance: 0.5081011511961054
# Distance a: 0.36557813847224013
# Distance: 0.7146371229529194
# Distance a: 0.36557813847224013
# Distance: 0.17729260723300108
# Distance a: 0.36557813847224013
# Distance: 0.4864871153058111
# Distance a: 0.36557813847224013
# Distance: 0.43475931538788753
# Distance a: 0.36557813847224013
# Distance: 0.2121689346708501
# Distance a: 0.36557813847224013
# Distance: 0.5101193559492737
# Distance a: 0.36557813847224013
# Distance: 0.4032584672322063
# Distance a: 0.36557813847224013
# Distance: 0.5079952784280647
# Distance a: 0.36557813847224013
# Distance: 0.842115499741399
# Distance a: 0.36557813847224013
# Distance: 0.6690945329173672
# Distance a: 0.36557813847224013
# Distance: 0.5796710779675691
# Distance a: 0.36557813847224013
# Distance: 0.7203549253750181
# Distance a: 0.36557813847224013
# Distance: 0.4772834972177621
# Distance a: 0.36557813847224013
# Distance: 0.10478806802666964
# Distance a: 0.36557813847224013
# Distance: 0.5599209130089154
# Distance a: 0.36557813847224013
# Distance: 0.3772460668518135
# Distance a: 0.36557813847224013
# Distance: 0.43077019641314546
# Distance a: 0.36557813847224013
# Distance: 1.0019338768276262
# Distance a: 0.36557813847224013
# Distance: 1.049866135810534
# Distance a: 0.36557813847224013
# Distance: 0.7287516202164286
# Distance a: 0.36557813847224013
# Distance: 0.3933544818970191
# Distance a: 0.36557813847224013
# Distance: 0.481325220261572
# Distance a: 0.36557813847224013
# Distance: 0.7409549637889371
# Distance a: 0.36557813847224013
# Distance: 0.4291621418217092
# Distance a: 0.36557813847224013
# Distance: 0.940582463305391
# Distance a: 0.36557813847224013
# Distance: 0.4597156917058106
# Distance a: 0.36557813847224013
# Distance: 0.536480652585242
# Distance a: 0.36557813847224013
# Distance: 0.49849229258799
# Distance a: 0.36557813847224013
# Distance: 0.5709831773774139
# Distance a: 0.36557813847224013
# Distance: 0.6629728806203014
# Distance a: 0.36557813847224013
# Distance: 0.43112611045283045
# Distance a: 0.36557813847224013
# Distance: 0.680348923454866
# Distance a: 0.36557813847224013
# Distance: 0.9896360944370264
# Distance a: 0.36557813847224013
# Distance: 0.022200409190886023
# Distance a: 0.36557813847224013
# Distance: 0.44734260011349936
# Distance a: 0.36557813847224013
# Distance: 0.1292122160162238
# Distance a: 0.36557813847224013
# Distance: 0.5580692518284799
# Distance a: 0.36557813847224013
# Distance: 0.03991120627898393
# Distance a: 0.36557813847224013
# Distance: 0.6843387561990129
# Distance a: 0.36557813847224013
# Distance: 0.5219855362960134
# Distance a: 0.36557813847224013
# Distance: 0.7199855308868467
# Distance a: 0.36557813847224013
# Distance: 0.8220140251303841
# Distance a: 0.36557813847224013
# Distance: 0.3648316195815652
# Distance a: 0.36557813847224013
# Distance: 0.4601115097838897
# Distance a: 0.36557813847224013
# Distance: 0.647237351051163
# Distance a: 0.36557813847224013
# Distance: 0.41813684745540686
# Distance a: 0.36557813847224013
# Distance: 0.16739721592806936
# Distance a: 0.36557813847224013
# Distance: 0.975570653045452
# Distance a: 0.36557813847224013
# Distance: 0.2996603735304842
# Distance a: 0.36557813847224013
# Distance: 0.4331322286351119
# Distance a: 0.36557813847224013
# Distance: 0.29231884042587314
# Distance a: 0.36557813847224013
# Distance: 0.8735651966275947
# Distance a: 0.36557813847224013
# Distance: 0.9187798923679474
# Distance a: 0.36557813847224013
# Distance: 0.3928670374305196
# Distance a: 0.36557813847224013
# Distance: 0.05844863303083908
# Distance a: 0.36557813847224013
# Distance: 0.6608446740335351
# Distance a: 0.36557813847224013
# Distance: 0.4713820410608806
# Distance a: 0.36557813847224013
# Distance: 0.001920530944925208
# Distance a: 0.36557813847224013
# Distance: 0.43329922568482626
# Distance a: 0.36557813847224013
# Distance: 0.849983833062844
# Distance a: 0.36557813847224013
# Distance: 0.5655275981715837
# Distance a: 0.36557813847224013
# Distance: 0.7362148127554078
# Distance a: 0.36557813847224013
# Distance: 0.29453463768762533
# Distance a: 0.36557813847224013
# Distance: 0.8176369302254458
# Distance a: 0.36557813847224013
# Distance: 0.569130434066609
# Distance a: 0.36557813847224013
# Distance: 0.30885842306547234
# Distance a: 0.36557813847224013
# Distance: 0.41197937375520893
# Distance a: 0.36557813847224013
# Distance: 0.25578546334204744
# Distance a: 0.36557813847224013
# Distance: 0.5367352173865952
# Distance a: 0.36557813847224013
# Distance: 1.0441093154038121
# Distance a: 0.36557813847224013
# Distance: 0.4590783750081014
# Distance a: 0.36557813847224013
# Distance: 0.8359413283200909
# Distance a: 0.36557813847224013
# Distance: 0.757066893840111
# Distance a: 0.36557813847224013
# Distance: 0.2831935298483202
# Distance a: 0.36557813847224013
# Distance: 0.48119986575149093
# Distance a: 0.36557813847224013
# Distance: 0.5169814006259746
# Distance a: 0.36557813847224013
# Distance: 0.6102723393715156
# Distance a: 0.36557813847224013
# Distance: 0.6035434751486678
# Distance a: 0.36557813847224013
# Distance: 0.49526001981820195
# Distance a: 0.36557813847224013
# Distance: 0.45212009599924513
# Distance a: 0.36557813847224013
# Distance: 0.5732372922984982
# Distance a: 0.36557813847224013
# Distance: 0.7561819588283588
# Distance a: 0.36557813847224013
# Distance: 0.8902514901259804
# Distance a: 0.36557813847224013
# Distance: 0.4539404139524038
# Distance a: 0.36557813847224013
# Distance: 0.603806084222002
# Distance a: 0.36557813847224013
# Distance: 0.7663950058794725
# Distance a: 0.36557813847224013
# Distance: 0.5196704081137411
# Distance a: 0.36557813847224013
# Distance: 0.3965478826988239
# Distance a: 0.36557813847224013
# Distance: 0.185492900238744
# Distance a: 0.36557813847224013
# Distance: 0.9791871968931368
# Distance a: 0.36557813847224013
# Distance: 0.06815625354111164
# Distance a: 0.36557813847224013
# Distance: 0.24149216318181949
# Distance a: 0.36557813847224013
# Distance: 0.5563749367623715
# Distance a: 0.36557813847224013
# Distance: 0.9512230440140782
# Distance a: 0.36557813847224013
# Distance b: 0.36557813847224013
# Distance c (computed using the Pythagorean theorem): 0.6202507147618271
# Perpendicular distance from point to plane: 0.9512230440140782
